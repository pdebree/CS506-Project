# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
plt.style.use('ggplot')

import folium
from folium.plugins import HeatMap
import geopy
from geopy.geocoders import Nominatim
from folium.vector_layers import CircleMarker

import os
from IPython.core.display import HTML

# %%
# Data Import - Read in Cleaned CSV File (Cleaned in contracts_cleaning.ipynb)
contracts = pd.read_csv("data_119/contracts.csv")

# %%
# Edit Recipient Names (if duplicates found in minority outputs)
contracts['recipient_name'] = contracts['recipient_name'].replace({'BAYASSOCIATES INCORPORATED':'BAYASSOCIATES, INC.', 'BAYASSOCIATES, INC': 'BAYASSOCIATES, INC.'})
contracts['recipient_name'] = contracts['recipient_name'].replace({'TERESA TRIANA':'TERESA, TRIANA'})
contracts['recipient_name'] =  contracts['recipient_name'].replace({'BEATRICE COCKRELL':'COCKRELL, BEATRICE'})

# %%
# Create Shorthands for Funding Agencies 
contracts['funding_agency_name'] = contracts['funding_agency_name'].replace({'DEPARTMENT OF HOUSING AND URBAN DEVELOPMENT (HUD)': 'HUD',
                                                                            'ENVIRONMENTAL PROTECTION AGENCY (EPA)': 'EPA',
                                                                            'DEPARTMENT OF HEALTH AND HUMAN SERVICES (HHS)': 'HHS',
                                                                            'NATIONAL SCIENCE FOUNDATION (NSF)' : 'NSF',
                                                                            'DEPARTMENT OF TRANSPORTATION (DOT)': 'DOT'})

# %%
contracts['recipient_city_name'] = contracts['recipient_city_name'] + ', MA'

# %%
# Creates a dataframe with the number of each type of naics (a business type classification)
naics = contracts.groupby(['naics_description'])[['contract_award_unique_key']].count()

# %%
# Creates a dataframe with the naics occur the most (the top 25, roughly more than 100 appearances each)
top_naics = naics.sort_values(by='contract_award_unique_key', ascending=False)[:25].index
contracts['top_naics'] = contracts['naics_description'].isin(top_naics)

# %%
top_naics
# Out:
# Index(['ANALYTICAL LABORATORY INSTRUMENT MANUFACTURING', 'OFFICES OF LAWYERS',
#        'OTHER ELECTRONIC AND PRECISION EQUIPMENT REPAIR AND MAINTENANCE',
#        'SURGICAL AND MEDICAL INSTRUMENT MANUFACTURING',
#        'ENVIRONMENTAL CONSULTING SERVICES',
#        'ADMINISTRATIVE MANAGEMENT AND GENERAL MANAGEMENT CONSULTING SERVICES',
#        'SOFTWARE PUBLISHERS', 'RESEARCH AND DEVELOPMENT IN BIOTECHNOLOGY',
#        'BIOLOGICAL PRODUCT (EXCEPT DIAGNOSTIC) MANUFACTURING',
#        'TESTING LABORATORIES',
#        'OFFICES OF PHYSICIANS (EXCEPT MENTAL HEALTH SPECIALISTS)',
#        'SURGICAL APPLIANCE AND SUPPLIES MANUFACTURING',
#        'ALL OTHER PROFESSIONAL, SCIENTIFIC, AND TECHNICAL SERVICES',
#        'RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGINEERING, AND LIFE SCIENCES (EXCEPT BIOTECHNOLOGY)',
#        'OTHER MEASURING AND CONTROLLING DEVICE MANUFACTURING',
#        'MEDICAL, DENTAL, AND HOSPITAL EQUIPMENT AND SUPPLIES MERCHANT WHOLESALERS',
#        'ELECTROMEDICAL AND ELECTROTHERAPEUTIC APPARATUS MANUFACTURING',
#        'VETERINARY SERVICES',
#        'OTHER SCIENTIFIC AND TECHNICAL CONSULTING SERVICES',
#        'OTHER COMPUTER RELATED SERVICES', 'ALL OTHER ANIMAL PRODUCTION',
#        'IN-VITRO DIAGNOSTIC SUBSTANCE MANUFACTURING',
#        'CUSTOM COMPUTER PROGRAMMING SERVICES',
#        'ALL OTHER BASIC ORGANIC CHEMICAL MANUFACTURING',
#        'OFFICE FURNITURE (EXCEPT WOOD) MANUFACTURING'],
#       dtype='object', name='naics_description')

# %%
contracts
# Out:
#                                contract_award_unique_key  obligated_amount  \
# 0                   CONT_AWD_00002_8600_DU100G16D01_8600        2286766.33
# 1                   CONT_AWD_00003_8600_DU100G16D01_8600        2396100.30
# 2                       CONT_AWD_0001_6800_EPC11039_6800          73525.06
# 3                       CONT_AWD_0001_6800_EPC12029_6800           8015.00
# 4                       CONT_AWD_0001_6800_EPC12051_6800          67492.86
# 5                       CONT_AWD_0001_6800_EPC12053_6800         295228.76
# 6                       CONT_AWD_0001_6800_EPC16015_6800           1659.68
# 7                       CONT_AWD_0001_6800_EPC17017_6800           5094.00
# 8                       CONT_AWD_0001_6800_EPD13013_6800           1250.00
# 9                       CONT_AWD_0001_6800_EPD14005_6800         114731.00
# 10                      CONT_AWD_0001_6800_EPD14030_6800          32634.00
# 11                      CONT_AWD_0001_6800_EPR11301_6800          69056.69
# 12                      CONT_AWD_0001_6800_EPR11302_6800          32935.97
# 13                      CONT_AWD_0001_6800_EPR51108_6800          53194.30
# 14                      CONT_AWD_0001_6800_EPR91604_6800         281002.02
# 15                      CONT_AWD_0001_6800_EPS11103_6800        1880789.41
# 16                      CONT_AWD_0001_6800_EPS11701_6800         556984.75
# 17                      CONT_AWD_0001_6800_EPW11022_6800         656579.11
# 18                      CONT_AWD_0001_6800_EPW11028_6800          85913.27
# 19                      CONT_AWD_0001_6800_EPW11053_6800         655809.00
# 20                      CONT_AWD_0001_6800_EPW14032_6800         596588.00
# 21                      CONT_AWD_0001_6800_EPW16002_6800        7749767.78
# 22                      CONT_AWD_0001_6800_EPW16023_6800           6436.00
# 23                      CONT_AWD_0001_6800_EPW17001_6800         241426.74
# 24                      CONT_AWD_0001_6800_EPW17005_6800         284308.00
# 25                 CONT_AWD_0001_9700_W912WJ17D0002_9700         546034.52
# 26                      CONT_AWD_0002_6800_EPC11039_6800           5520.56
# 27                      CONT_AWD_0002_6800_EPC12053_6800          85764.97
# 28                      CONT_AWD_0002_6800_EPC16015_6800          15824.00
# 29                      CONT_AWD_0002_6800_EPD13013_6800         330000.00
# ...                                                  ...               ...
# 18453         CONT_AWD_75P00218P00227_7570_-NONE-_-NONE-          25995.00
# 18454         CONT_AWD_75N90018P00435_7529_-NONE-_-NONE-          45424.00
# 18455         CONT_AWD_75N91018P00339_7529_-NONE-_-NONE-          12180.00
# 18456         CONT_AWD_75N94018P00307_7529_-NONE-_-NONE-           3979.00
# 18457         CONT_AWD_75N98C18K00016_7529_-NONE-_-NONE-          12180.00
# 18458         CONT_AWD_75N94018P00320_7529_-NONE-_-NONE-          11964.00
# 18459         CONT_AWD_75N94018P00300_7529_-NONE-_-NONE-          52530.07
# 18460  CONT_AWD_75N98018F02400_7529_HHSN263200900007I...           6065.00
# 18461  CONT_AWD_75N98018F00195_7529_HHSN263200900028I...           6065.00
# 18462  CONT_AWD_75N98018F02394_7529_HHSN263200900007I...           7220.50
# 18463  CONT_AWD_75N98018F02398_7529_HHSN263200900007I...           3877.50
# 18464  CONT_AWD_75N98018F02402_7529_HHSN263200900007I...           5942.50
# 18465  CONT_AWD_75N98018F02403_7529_HHSN263200900007I...           4339.00
# 18466  CONT_AWD_75N98018F02396_7529_HHSN263200900007I...          21605.00
# 18467  CONT_AWD_75N98018F02401_7529_HHSN263200900007I...           8760.00
# 18468         CONT_AWD_75F40118P10111_7524_-NONE-_-NONE-           4036.00
# 18469         CONT_AWD_75N97018K00012_7529_-NONE-_-NONE-           7875.00
# 18470  CONT_AWD_75N98018F01045_7529_HHSN263201200094B...          11520.88
# 18471         CONT_AWD_75N93018P00692_7529_-NONE-_-NONE-           8935.00
# 18472       CONT_AWD_75N90018F00075_7529_V797P2238D_3600         114440.39
# 18473         CONT_AWD_75N91018P00346_7529_-NONE-_-NONE-          17909.01
# 18474  CONT_AWD_75R60218F44043_7526_HHSH250201500032B...          12200.00
# 18475         CONT_AWD_75N95A18K00001_7529_-NONE-_-NONE-           3509.00
# 18476         CONT_AWD_75N93018P00649_7529_-NONE-_-NONE-          16750.00
# 18477       CONT_AWD_75N94018F00076_7529_GS07F5933R_4730           3978.14
# 18478         CONT_AWD_75H71518P00021_7527_-NONE-_-NONE-           6625.17
# 18479         CONT_AWD_75D30119P06908_7523_-NONE-_-NONE-          25400.00
# 18480         CONT_AWD_75D30119C05099_7523_-NONE-_-NONE-          88588.56
# 18481     CONT_AWD_68HE0119F0016_6800_68HE0119D0001_6800           8869.00
# 18482         CONT_AWD_75D30119P06949_7523_-NONE-_-NONE-          44022.00
#
#       period_of_performance_start_date period_of_performance_current_end_date  \
# 0                              1/20/17                           1/19/18 0:00
# 1                              1/20/18                           1/19/19 0:00
# 2                              8/28/12                           3/31/14 0:00
# 3                              11/2/12                            2/1/13 0:00
# 4                               9/9/13                           8/31/17 0:00
# 5                              5/28/13                           3/27/18 0:00
# 6                              2/14/17                           4/28/17 0:00
# 7                              8/31/17                          12/17/17 0:00
# 8                              5/29/14                           5/28/15 0:00
# 9                              4/24/14                           4/14/19 0:00
# 10                             10/3/14                           9/30/19 0:00
# 11                             9/10/13                            9/9/14 0:00
# 12                             9/10/13                            9/8/18 0:00
# 13                             7/27/11                           7/26/13 0:00
# 14                             7/27/16                           7/31/17 0:00
# 15                             9/23/11                           6/22/17 0:00
# 16                             4/12/17                            4/4/22 0:00
# 17                              3/1/11                           2/29/12 0:00
# 18                              4/6/11                           4/30/15 0:00
# 19                             5/23/12                           7/21/13 0:00
# 20                            11/24/14                            2/8/18 0:00
# 21                              4/5/16                            4/4/20 0:00
# 22                             3/22/17                           3/31/18 0:00
# 23                              4/7/17                            4/6/20 0:00
# 24                             11/4/16                           2/28/18 0:00
# 25                             4/28/17                           6/30/20 0:00
# 26                             8/15/12                           2/16/13 0:00
# 27                             6/10/13                           2/28/17 0:00
# 28                             2/16/17                           9/30/17 0:00
# 29                             1/26/16                           1/25/17 0:00
# ...                                ...                                    ...
# 18453                           5/8/18                            5/8/18 0:00
# 18454                           5/4/18                           5/14/18 0:00
# 18455                           5/4/18                            5/3/19 0:00
# 18456                           5/8/18                           11/7/18 0:00
# 18457                           5/9/18                            5/9/18 0:00
# 18458                          5/10/18                           3/31/19 0:00
# 18459                           5/4/18                           7/31/19 0:00
# 18460                           5/8/18                           4/26/19 0:00
# 18461                           5/8/18                            8/2/19 0:00
# 18462                           5/8/18                           4/26/19 0:00
# 18463                           5/8/18                           4/26/19 0:00
# 18464                           5/8/18                           4/26/19 0:00
# 18465                           5/8/18                           4/26/19 0:00
# 18466                           5/8/18                           4/26/19 0:00
# 18467                           5/8/18                           4/26/19 0:00
# 18468                          5/10/18                           5/20/18 0:00
# 18469                          5/10/18                           5/10/18 0:00
# 18470                          5/11/18                           1/31/19 0:00
# 18471                          5/11/18                           8/31/18 0:00
# 18472                          5/11/18                           5/25/18 0:00
# 18473                          5/10/18                            4/2/19 0:00
# 18474                          5/12/18                           4/11/19 0:00
# 18475                          5/11/18                           5/11/18 0:00
# 18476                          5/11/18                           6/15/19 0:00
# 18477                          5/11/18                           5/10/19 0:00
# 18478                         12/28/17                           9/30/20 0:00
# 18479                          9/20/19                          10/20/19 0:00
# 18480                          6/28/19                           6/27/20 0:00
# 18481                          7/26/19                           7/21/20 0:00
# 18482                          9/23/19                          10/22/19 0:00
#
#       funding_agency_name                            funding_sub_agency_name  \
# 0                     HUD       HOUSING AND URBAN DEVELOPMENT, DEPARTMENT OF
# 1                     HUD       HOUSING AND URBAN DEVELOPMENT, DEPARTMENT OF
# 2                     EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 3                     EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 4                     EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 5                     EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 6                     EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 7                     EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 8                     EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 9                     EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 10                    EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 11                    EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 12                    EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 13                    EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 14                    EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 15                    EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 16                    EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 17                    EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 18                    EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 19                    EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 20                    EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 21                    EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 22                    EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 23                    EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 24                    EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 25                    EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 26                    EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 27                    EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 28                    EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 29                    EPA                    ENVIRONMENTAL PROTECTION AGENCY
# ...                   ...                                                ...
# 18453                 HHS  OFFICE OF THE ASSISTANT SECRETARY FOR ADMINIST...
# 18454                 HHS                      NATIONAL INSTITUTES OF HEALTH
# 18455                 HHS                      NATIONAL INSTITUTES OF HEALTH
# 18456                 HHS                      NATIONAL INSTITUTES OF HEALTH
# 18457                 HHS                      NATIONAL INSTITUTES OF HEALTH
# 18458                 HHS                      NATIONAL INSTITUTES OF HEALTH
# 18459                 HHS                      NATIONAL INSTITUTES OF HEALTH
# 18460                 HHS                      NATIONAL INSTITUTES OF HEALTH
# 18461                 HHS                      NATIONAL INSTITUTES OF HEALTH
# 18462                 HHS                      NATIONAL INSTITUTES OF HEALTH
# 18463                 HHS                      NATIONAL INSTITUTES OF HEALTH
# 18464                 HHS                      NATIONAL INSTITUTES OF HEALTH
# 18465                 HHS                      NATIONAL INSTITUTES OF HEALTH
# 18466                 HHS                      NATIONAL INSTITUTES OF HEALTH
# 18467                 HHS                      NATIONAL INSTITUTES OF HEALTH
# 18468                 HHS                       FOOD AND DRUG ADMINISTRATION
# 18469                 HHS                      NATIONAL INSTITUTES OF HEALTH
# 18470                 HHS                      NATIONAL INSTITUTES OF HEALTH
# 18471                 HHS                      NATIONAL INSTITUTES OF HEALTH
# 18472                 HHS                      NATIONAL INSTITUTES OF HEALTH
# 18473                 HHS                      NATIONAL INSTITUTES OF HEALTH
# 18474                 HHS       HEALTH RESOURCES AND SERVICES ADMINISTRATION
# 18475                 HHS                      NATIONAL INSTITUTES OF HEALTH
# 18476                 HHS                      NATIONAL INSTITUTES OF HEALTH
# 18477                 HHS                      NATIONAL INSTITUTES OF HEALTH
# 18478                 HHS                              INDIAN HEALTH SERVICE
# 18479                 HHS         CENTERS FOR DISEASE CONTROL AND PREVENTION
# 18480                 HHS         CENTERS FOR DISEASE CONTROL AND PREVENTION
# 18481                 EPA                    ENVIRONMENTAL PROTECTION AGENCY
# 18482                 HHS         CENTERS FOR DISEASE CONTROL AND PREVENTION
#
#                                       recipient_name  \
# 0                 STATE STREET GLOBAL ADVISORS, INC.
# 1                STATE STREET BANK AND TRUST COMPANY
# 2                            CADMUS GROUP, INC., THE
# 3                       EASTERN RESEARCH GROUP, INC.
# 4                                ABT ASSOCIATES INC.
# 5                            CADMUS GROUP, INC., THE
# 6                       EASTERN RESEARCH GROUP, INC.
# 7                       EASTERN RESEARCH GROUP, INC.
# 8                                       APREDICA LLC
# 9                  GE HEALTHCARE BIO-SCIENCES, CORP.
# 10                      EASTERN RESEARCH GROUP, INC.
# 11                                          AGP, LLC
# 12              MIDDLESEX GASES & TECHNOLOGIES, INC.
# 13        CLEAN HARBORS ENVIRONMENTAL SERVICES, INC.
# 14                        HORSLEY WITTEN GROUP, INC.
# 15                         H&S/NOBIS ENVIRONENTAL JV
# 16                                      KGSNE JV LLC
# 17                           CADMUS GROUP, INC., THE
# 18                        MABBETT & ASSOCIATES, INC.
# 19                      EASTERN RESEARCH GROUP, INC.
# 20                EUROFINS SPECTRUM ANALYTICAL, INC.
# 21                      EASTERN RESEARCH GROUP, INC.
# 22                INDUSTRIAL ECONOMICS, INCORPORATED
# 23                               ABT ASSOCIATES INC.
# 24                      EASTERN RESEARCH GROUP, INC.
# 25                     MINUTEMAN DESIGN VENTURES LLC
# 26                           CADMUS GROUP, INC., THE
# 27                           CADMUS GROUP, INC., THE
# 28                      EASTERN RESEARCH GROUP, INC.
# 29                                      APREDICA LLC
# ...                                              ...
# 18453                       ZOLL MEDICAL CORPORATION
# 18454                  BOSTON SCIENTIFIC CORPORATION
# 18455                        NEXCELOM BIOSCIENCE LLC
# 18456                     PRESSURE BIOSCIENCES, INC.
# 18457                        NEXCELOM BIOSCIENCE LLC
# 18458                  EVOQUA WATER TECHNOLOGIES LLC
# 18459                       GENERAL ELECTRIC COMPANY
# 18460              EDWARDS ANGELL PALMER & DODGE LLP
# 18461              EDWARDS ANGELL PALMER & DODGE LLP
# 18462              EDWARDS ANGELL PALMER & DODGE LLP
# 18463              EDWARDS ANGELL PALMER & DODGE LLP
# 18464              EDWARDS ANGELL PALMER & DODGE LLP
# 18465              EDWARDS ANGELL PALMER & DODGE LLP
# 18466              EDWARDS ANGELL PALMER & DODGE LLP
# 18467              EDWARDS ANGELL PALMER & DODGE LLP
# 18468                WATERS TECHNOLOGIES CORPORATION
# 18469                              ESM SOFTWARE, LLC
# 18470                                  WESTNET, INC.
# 18471                      EMD MILLIPORE CORPORATION
# 18472  PHILIPS ELECTRONICS NORTH AMERICA CORPORATION
# 18473                                        BIOVIEW
# 18474                             VARTANIAN, TIMOTHY
# 18475                                      ABCAM INC
# 18476                                  COVARIS, INC.
# 18477                           OLYMPUS AMERICA INC.
# 18478                             BOSTON GAS COMPANY
# 18479                               DENATOR US CORP.
# 18480                          BRUKER SCIENTIFIC LLC
# 18481                             ATAASK GLOBAL INC.
# 18482            HAMILTON STORAGE TECHNOLOGIES, INC.
#
#       primary_place_of_performance_county_name recipient_city_name  \
# 0                                      SUFFOLK          BOSTON, MA
# 1                                      SUFFOLK          BOSTON, MA
# 2                                    MIDDLESEX       WATERTOWN, MA
# 3                                    MIDDLESEX       LEXINGTON, MA
# 4                                    MIDDLESEX       CAMBRIDGE, MA
# 5                                    MIDDLESEX       WATERTOWN, MA
# 6                                    MIDDLESEX       LEXINGTON, MA
# 7                                    MIDDLESEX       LEXINGTON, MA
# 8                                    MIDDLESEX       WATERTOWN, MA
# 9                                       DURHAM     MARLBOROUGH, MA
# 10                                   MIDDLESEX       LEXINGTON, MA
# 11                                   MIDDLESEX         EVERETT, MA
# 12                                   MIDDLESEX         EVERETT, MA
# 13                                     SUFFOLK         NORWELL, MA
# 14                               SAN FRANCISCO        SANDWICH, MA
# 15                                     SUFFOLK     WESTBOROUGH, MA
# 16                                     SUFFOLK     WESTBOROUGH, MA
# 17                                   MIDDLESEX       WATERTOWN, MA
# 18                                     SUFFOLK         BEDFORD, MA
# 19                                   MIDDLESEX       LEXINGTON, MA
# 20                                  WASHINGTON          AGAWAM, MA
# 21                                   MIDDLESEX       LEXINGTON, MA
# 22                                   MIDDLESEX       CAMBRIDGE, MA
# 23                                   MIDDLESEX       CAMBRIDGE, MA
# 24                                   MIDDLESEX       LEXINGTON, MA
# 25                                   FAIRFIELD          BOSTON, MA
# 26                                   MIDDLESEX       WATERTOWN, MA
# 27                                   MIDDLESEX       WATERTOWN, MA
# 28                                   MIDDLESEX       LEXINGTON, MA
# 29                                   MIDDLESEX       WATERTOWN, MA
# ...                                        ...                 ...
# 18453                                MIDDLESEX      CHELMSFORD, MA
# 18454                               MONTGOMERY     MARLBOROUGH, MA
# 18455                                    ESSEX        LAWRENCE, MA
# 18456                                  BRISTOL    SOUTH EASTON, MA
# 18457                                    ESSEX        LAWRENCE, MA
# 18458                                MIDDLESEX          LOWELL, MA
# 18459                                    WAYNE            LYNN, MA
# 18460                                  SUFFOLK          BOSTON, MA
# 18461                                  SUFFOLK          BOSTON, MA
# 18462                                  SUFFOLK          BOSTON, MA
# 18463                                  SUFFOLK          BOSTON, MA
# 18464                                  SUFFOLK          BOSTON, MA
# 18465                                  SUFFOLK          BOSTON, MA
# 18466                                  SUFFOLK          BOSTON, MA
# 18467                                  SUFFOLK          BOSTON, MA
# 18468                                WORCESTER         MILFORD, MA
# 18469                                MIDDLESEX         LINCOLN, MA
# 18470                                  NORFOLK          CANTON, MA
# 18471                               MONTGOMERY      BURLINGTON, MA
# 18472                               MONTGOMERY         ANDOVER, MA
# 18473                               MONTGOMERY       BILLERICA, MA
# 18474                                  NORFOLK       BROOKLINE, MA
# 18475                                MIDDLESEX       CAMBRIDGE, MA
# 18476                                MIDDLESEX          WOBURN, MA
# 18477                               MONTGOMERY         WALTHAM, MA
# 18478                               BARNSTABLE         WALTHAM, MA
# 18479                                MIDDLESEX       CAMBRIDGE, MA
# 18480                                   DEKALB       BILLERICA, MA
# 18481                                  SUFFOLK          MALDEN, MA
# 18482                                SAN MATEO        FRANKLIN, MA
#
#                                        naics_description  ...  \
# 0                                      INVESTMENT ADVICE  ...
# 1                                      INVESTMENT ADVICE  ...
# 2      RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...  ...
# 3                      ENVIRONMENTAL CONSULTING SERVICES  ...
# 4      ADMINISTRATIVE MANAGEMENT AND GENERAL MANAGEME...  ...
# 5      ADMINISTRATIVE MANAGEMENT AND GENERAL MANAGEME...  ...
# 6      RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...  ...
# 7      ALL OTHER PROFESSIONAL, SCIENTIFIC, AND TECHNI...  ...
# 8      RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...  ...
# 9         ANALYTICAL LABORATORY INSTRUMENT MANUFACTURING  ...
# 10                                  TESTING LABORATORIES  ...
# 11                          INDUSTRIAL GAS MANUFACTURING  ...
# 12                          INDUSTRIAL GAS MANUFACTURING  ...
# 13                            HAZARDOUS WASTE COLLECTION  ...
# 14                     ENVIRONMENTAL CONSULTING SERVICES  ...
# 15                                  REMEDIATION SERVICES  ...
# 16                                  REMEDIATION SERVICES  ...
# 17                         MARKETING CONSULTING SERVICES  ...
# 18                     ENVIRONMENTAL CONSULTING SERVICES  ...
# 19                     ENVIRONMENTAL CONSULTING SERVICES  ...
# 20                                  TESTING LABORATORIES  ...
# 21                     ENVIRONMENTAL CONSULTING SERVICES  ...
# 22     ALL OTHER PROFESSIONAL, SCIENTIFIC, AND TECHNI...  ...
# 23                     ENVIRONMENTAL CONSULTING SERVICES  ...
# 24     OTHER SCIENTIFIC AND TECHNICAL CONSULTING SERV...  ...
# 25                                  ENGINEERING SERVICES  ...
# 26     RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...  ...
# 27     ADMINISTRATIVE MANAGEMENT AND GENERAL MANAGEME...  ...
# 28     RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...  ...
# 29     RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...  ...
# ...                                                  ...  ...
# 18453      SURGICAL APPLIANCE AND SUPPLIES MANUFACTURING  ...
# 18454      SURGICAL AND MEDICAL INSTRUMENT MANUFACTURING  ...
# 18455     ANALYTICAL LABORATORY INSTRUMENT MANUFACTURING  ...
# 18456     ANALYTICAL LABORATORY INSTRUMENT MANUFACTURING  ...
# 18457     ANALYTICAL LABORATORY INSTRUMENT MANUFACTURING  ...
# 18458                WATER SUPPLY AND IRRIGATION SYSTEMS  ...
# 18459  OTHER ELECTRONIC AND PRECISION EQUIPMENT REPAI...  ...
# 18460                                 OFFICES OF LAWYERS  ...
# 18461                                 OFFICES OF LAWYERS  ...
# 18462                                 OFFICES OF LAWYERS  ...
# 18463                                 OFFICES OF LAWYERS  ...
# 18464                                 OFFICES OF LAWYERS  ...
# 18465                                 OFFICES OF LAWYERS  ...
# 18466                                 OFFICES OF LAWYERS  ...
# 18467                                 OFFICES OF LAWYERS  ...
# 18468  OTHER ELECTRONIC AND PRECISION EQUIPMENT REPAI...  ...
# 18469                    OTHER COMPUTER RELATED SERVICES  ...
# 18470      SURGICAL AND MEDICAL INSTRUMENT MANUFACTURING  ...
# 18471  OTHER ELECTRONIC AND PRECISION EQUIPMENT REPAI...  ...
# 18472  ELECTROMEDICAL AND ELECTROTHERAPEUTIC APPARATU...  ...
# 18473  OTHER ELECTRONIC AND PRECISION EQUIPMENT REPAI...  ...
# 18474  OFFICES OF PHYSICIANS (EXCEPT MENTAL HEALTH SP...  ...
# 18475  BIOLOGICAL PRODUCT (EXCEPT DIAGNOSTIC) MANUFAC...  ...
# 18476  OTHER ELECTRONIC AND PRECISION EQUIPMENT REPAI...  ...
# 18477  OTHER MEASURING AND CONTROLLING DEVICE MANUFAC...  ...
# 18478                           NATURAL GAS DISTRIBUTION  ...
# 18479      SURGICAL AND MEDICAL INSTRUMENT MANUFACTURING  ...
# 18480     ANALYTICAL LABORATORY INSTRUMENT MANUFACTURING  ...
# 18481  SERVICES FOR THE ELDERLY AND PERSONS WITH DISA...  ...
# 18482      SURGICAL AND MEDICAL INSTRUMENT MANUFACTURING  ...
#
#        us_government_entity  educational_institution manufacturer_of_goods  \
# 0                     False                    False                 False
# 1                     False                    False                 False
# 2                     False                    False                 False
# 3                     False                    False                 False
# 4                     False                    False                 False
# 5                     False                    False                 False
# 6                     False                    False                 False
# 7                     False                    False                 False
# 8                     False                    False                 False
# 9                     False                    False                  True
# 10                    False                    False                 False
# 11                    False                    False                  True
# 12                    False                    False                 False
# 13                    False                    False                 False
# 14                    False                    False                 False
# 15                    False                    False                 False
# 16                    False                    False                 False
# 17                    False                    False                 False
# 18                    False                    False                 False
# 19                    False                    False                 False
# 20                    False                    False                 False
# 21                    False                    False                 False
# 22                    False                    False                 False
# 23                    False                    False                 False
# 24                    False                    False                 False
# 25                    False                    False                 False
# 26                    False                    False                 False
# 27                    False                    False                 False
# 28                    False                    False                 False
# 29                    False                    False                 False
# ...                     ...                      ...                   ...
# 18453                 False                    False                  True
# 18454                 False                    False                 False
# 18455                 False                    False                  True
# 18456                 False                    False                  True
# 18457                 False                    False                  True
# 18458                 False                    False                 False
# 18459                 False                    False                  True
# 18460                 False                    False                 False
# 18461                 False                    False                 False
# 18462                 False                    False                 False
# 18463                 False                    False                 False
# 18464                 False                    False                 False
# 18465                 False                    False                 False
# 18466                 False                    False                 False
# 18467                 False                    False                 False
# 18468                 False                    False                  True
# 18469                 False                    False                 False
# 18470                 False                    False                 False
# 18471                 False                    False                  True
# 18472                 False                    False                  True
# 18473                 False                    False                  True
# 18474                 False                    False                 False
# 18475                 False                    False                  True
# 18476                 False                    False                 False
# 18477                 False                    False                  True
# 18478                 False                    False                 False
# 18479                 False                    False                 False
# 18480                 False                    False                  True
# 18481                 False                    False                 False
# 18482                 False                    False                 False
#
#        limited_liability_corporation  for_profit_organization  \
# 0                              False                     True
# 1                              False                     True
# 2                              False                     True
# 3                              False                     True
# 4                              False                     True
# 5                              False                     True
# 6                              False                     True
# 7                              False                     True
# 8                              False                     True
# 9                              False                     True
# 10                             False                     True
# 11                             False                     True
# 12                             False                     True
# 13                             False                     True
# 14                             False                     True
# 15                              True                     True
# 16                             False                     True
# 17                             False                     True
# 18                             False                     True
# 19                             False                     True
# 20                             False                     True
# 21                             False                     True
# 22                             False                     True
# 23                             False                     True
# 24                             False                     True
# 25                              True                     True
# 26                             False                     True
# 27                             False                     True
# 28                             False                     True
# 29                             False                     True
# ...                              ...                      ...
# 18453                          False                     True
# 18454                          False                     True
# 18455                           True                     True
# 18456                          False                     True
# 18457                           True                     True
# 18458                          False                     True
# 18459                          False                     True
# 18460                          False                     True
# 18461                          False                     True
# 18462                          False                     True
# 18463                          False                     True
# 18464                          False                     True
# 18465                          False                     True
# 18466                          False                     True
# 18467                          False                     True
# 18468                          False                     True
# 18469                          False                     True
# 18470                          False                     True
# 18471                          False                     True
# 18472                          False                     True
# 18473                          False                     True
# 18474                          False                     True
# 18475                          False                     True
# 18476                          False                     True
# 18477                          False                     True
# 18478                          False                     True
# 18479                          False                     True
# 18480                          False                     True
# 18481                          False                     True
# 18482                          False                     True
#
#        nonprofit_organization  other_not_for_profit_organization  start_year  \
# 0                       False                              False          17
# 1                       False                              False          18
# 2                       False                              False          12
# 3                       False                              False          12
# 4                       False                              False          13
# 5                       False                              False          13
# 6                       False                              False          17
# 7                       False                              False          17
# 8                       False                              False          14
# 9                       False                              False          14
# 10                      False                              False          14
# 11                      False                              False          13
# 12                      False                              False          13
# 13                      False                              False          11
# 14                      False                              False          16
# 15                      False                              False          11
# 16                      False                              False          17
# 17                      False                              False          11
# 18                      False                              False          11
# 19                      False                              False          12
# 20                      False                              False          14
# 21                      False                              False          16
# 22                      False                              False          17
# 23                      False                              False          17
# 24                      False                              False          16
# 25                      False                              False          17
# 26                      False                              False          12
# 27                      False                              False          13
# 28                      False                              False          17
# 29                      False                              False          16
# ...                       ...                                ...         ...
# 18453                   False                              False          18
# 18454                   False                              False          18
# 18455                   False                              False          18
# 18456                   False                              False          18
# 18457                   False                              False          18
# 18458                   False                              False          18
# 18459                   False                              False          18
# 18460                   False                              False          18
# 18461                   False                              False          18
# 18462                   False                              False          18
# 18463                   False                              False          18
# 18464                   False                              False          18
# 18465                   False                              False          18
# 18466                   False                              False          18
# 18467                   False                              False          18
# 18468                   False                              False          18
# 18469                   False                              False          18
# 18470                   False                              False          18
# 18471                   False                              False          18
# 18472                   False                              False          18
# 18473                   False                              False          18
# 18474                   False                              False          18
# 18475                   False                              False          18
# 18476                   False                              False          18
# 18477                   False                              False          18
# 18478                   False                              False          17
# 18479                   False                              False          19
# 18480                   False                              False          19
# 18481                   False                              False          19
# 18482                   False                              False          19
#
#        end_year  top_naics
# 0          18.0      False
# 1          19.0      False
# 2          14.0       True
# 3          13.0       True
# 4          17.0       True
# 5          18.0       True
# 6          17.0       True
# 7          17.0       True
# 8          15.0       True
# 9          19.0       True
# 10         19.0       True
# 11         14.0      False
# 12         18.0      False
# 13         13.0      False
# 14         17.0       True
# 15         17.0      False
# 16         22.0      False
# 17         12.0      False
# 18         15.0       True
# 19         13.0       True
# 20         18.0       True
# 21         20.0       True
# 22         18.0       True
# 23         20.0       True
# 24         18.0       True
# 25         20.0      False
# 26         13.0       True
# 27         17.0       True
# 28         17.0       True
# 29         17.0       True
# ...         ...        ...
# 18453      18.0       True
# 18454      18.0       True
# 18455      19.0       True
# 18456      18.0       True
# 18457      18.0       True
# 18458      19.0      False
# 18459      19.0       True
# 18460      19.0       True
# 18461      19.0       True
# 18462      19.0       True
# 18463      19.0       True
# 18464      19.0       True
# 18465      19.0       True
# 18466      19.0       True
# 18467      19.0       True
# 18468      18.0       True
# 18469      18.0       True
# 18470      19.0       True
# 18471      18.0       True
# 18472      18.0       True
# 18473      19.0       True
# 18474      19.0       True
# 18475      18.0       True
# 18476      19.0       True
# 18477      19.0       True
# 18478      20.0      False
# 18479      19.0       True
# 18480      20.0       True
# 18481      20.0      False
# 18482      19.0       True
#
# [18483 rows x 29 columns]

# %%
geolocator = Nominatim(timeout=10)
cities = contracts['recipient_city_name'].unique()
# Out:
# /Users/pippidebree/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Using Nominatim with the default "geopy/1.20.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   """Entry point for launching an IPython kernel.

# %%
coords = pd.Series(cities).apply(geolocator.geocode).apply(lambda x: pd.Series({'Latitude':x.latitude, 'Longitude':x.longitude}))

# %%
cities = pd.Series(cities)
coords['recipient_city_name'] = cities

# %%
contracts = contracts.merge(coords, how='left', on='recipient_city_name')

# %%
contracts['Latitude_shuf'] = contracts['Latitude'].apply(lambda x: x + np.random.uniform(-0.01, 0.01))
contracts['Longitude_shuf'] =  contracts['Longitude'].apply(lambda x: x + np.random.uniform(-0.01, 0.01))

# %%
contracts['con_len'] = contracts['end_year'] - contracts['start_year']

# %%
# Create Sub-frames for Black, Hispanic and Minority Owned Businesses 
bbe = contracts.loc[contracts['black_american_owned_business'] == True]
hbe = contracts.loc[contracts['hispanic_american_owned_business'] == True]
mbe = contracts.loc[contracts['minority_owned_business'] == True]

# %%
# Reports all Black American Owned Businesses and the number grants they have recieved 
bbe.groupby(['recipient_name'])['contract_award_unique_key'].count()
# Out:
# recipient_name
# AKRIVIS TECHNOLOGIES, LLC              2
# APHIOS CORPORATION                     3
# ATAASK GLOBAL INC.                     2
# BAYASSOCIATES, INC.                    5
# BRYANT ASSOCIATES, INC.                2
# CLARENDON VALUATION ADVISORS, LLC      2
# COCKRELL, BEATRICE                     9
# GONA, PHILIMON                         1
# GORDON, PATRICK                        2
# HARLOW SCIENTIFIC, LLC                 1
# INTELIMAP INC                          2
# JMW SYSTEMS                            1
# WESTCARB ENTERPRISES, INC.             3
# WESTNET, INC.                        564
# WINDWALKER GROUP, LLC                  1
# Name: contract_award_unique_key, dtype: int64

# %%
# Reports all Black American Owned Businesses and the number grants they have recieved 
bbe.groupby(['recipient_name', 'naics_description'])['recipient_name', 'naics_description'].head()
# Out:
#                           recipient_name  \
# 62               BRYANT ASSOCIATES, INC.
# 112              BRYANT ASSOCIATES, INC.
# 551    CLARENDON VALUATION ADVISORS, LLC
# 769                      GORDON, PATRICK
# 791                        INTELIMAP INC
# 807                      GORDON, PATRICK
# 816                        INTELIMAP INC
# 6888          WESTCARB ENTERPRISES, INC.
# 6904          WESTCARB ENTERPRISES, INC.
# 6916          WESTCARB ENTERPRISES, INC.
# 7345                  APHIOS CORPORATION
# 7474           AKRIVIS TECHNOLOGIES, LLC
# 7532           AKRIVIS TECHNOLOGIES, LLC
# 7851                       WESTNET, INC.
# 7857                       WESTNET, INC.
# 7864                       WESTNET, INC.
# 7875                       WESTNET, INC.
# 7880                       WESTNET, INC.
# 10211                      WESTNET, INC.
# 10231                      WESTNET, INC.
# 10234                      WESTNET, INC.
# 10246                      WESTNET, INC.
# 10251                      WESTNET, INC.
# 10378                      WESTNET, INC.
# 10380                      WESTNET, INC.
# 10382                      WESTNET, INC.
# 10383                      WESTNET, INC.
# 10631                 APHIOS CORPORATION
# 10769                     GONA, PHILIMON
# 12684                 APHIOS CORPORATION
# 12805                      WESTNET, INC.
# 13409             HARLOW SCIENTIFIC, LLC
# 14108                        JMW SYSTEMS
# 15233                      WESTNET, INC.
# 15235                      WESTNET, INC.
# 15254                      WESTNET, INC.
# 15256                      WESTNET, INC.
# 15413                 COCKRELL, BEATRICE
# 15415                 COCKRELL, BEATRICE
# 15420                BAYASSOCIATES, INC.
# 15421                BAYASSOCIATES, INC.
# 15424                BAYASSOCIATES, INC.
# 15426                 COCKRELL, BEATRICE
# 15442                 COCKRELL, BEATRICE
# 15445                 COCKRELL, BEATRICE
# 15446                 COCKRELL, BEATRICE
# 15447                 COCKRELL, BEATRICE
# 15450                 COCKRELL, BEATRICE
# 15452                BAYASSOCIATES, INC.
# 15453                BAYASSOCIATES, INC.
# 15454                 COCKRELL, BEATRICE
# 16358              WINDWALKER GROUP, LLC
# 16433  CLARENDON VALUATION ADVISORS, LLC
# 17427                 ATAASK GLOBAL INC.
# 18481                 ATAASK GLOBAL INC.
#
#                                        naics_description
# 62     SURVEYING AND MAPPING (EXCEPT GEOPHYSICAL) SER...
# 112    SURVEYING AND MAPPING (EXCEPT GEOPHYSICAL) SER...
# 551                    OFFICES OF REAL ESTATE APPRAISERS
# 769                    ENVIRONMENTAL CONSULTING SERVICES
# 791                 OTHER MANAGEMENT CONSULTING SERVICES
# 807                              GRANTMAKING FOUNDATIONS
# 816                 OTHER MANAGEMENT CONSULTING SERVICES
# 6888                       HARDWARE MERCHANT WHOLESALERS
# 6904                       HARDWARE MERCHANT WHOLESALERS
# 6916                       HARDWARE MERCHANT WHOLESALERS
# 7345           RESEARCH AND DEVELOPMENT IN BIOTECHNOLOGY
# 7474           RESEARCH AND DEVELOPMENT IN BIOTECHNOLOGY
# 7532           RESEARCH AND DEVELOPMENT IN BIOTECHNOLOGY
# 7851       SURGICAL AND MEDICAL INSTRUMENT MANUFACTURING
# 7857       SURGICAL AND MEDICAL INSTRUMENT MANUFACTURING
# 7864       SURGICAL AND MEDICAL INSTRUMENT MANUFACTURING
# 7875       SURGICAL AND MEDICAL INSTRUMENT MANUFACTURING
# 7880       SURGICAL AND MEDICAL INSTRUMENT MANUFACTURING
# 10211  MEDICAL, DENTAL, AND HOSPITAL EQUIPMENT AND SU...
# 10231  MEDICAL, DENTAL, AND HOSPITAL EQUIPMENT AND SU...
# 10234  MEDICAL, DENTAL, AND HOSPITAL EQUIPMENT AND SU...
# 10246  MEDICAL, DENTAL, AND HOSPITAL EQUIPMENT AND SU...
# 10251  MEDICAL, DENTAL, AND HOSPITAL EQUIPMENT AND SU...
# 10378     ANALYTICAL LABORATORY INSTRUMENT MANUFACTURING
# 10380  OTHER PRESSED AND BLOWN GLASS AND GLASSWARE MA...
# 10382                  ELECTRONIC COMPUTER MANUFACTURING
# 10383  OTHER PRESSED AND BLOWN GLASS AND GLASSWARE MA...
# 10631  RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...
# 10769  RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...
# 12684          RESEARCH AND DEVELOPMENT IN BIOTECHNOLOGY
# 12805     ANALYTICAL LABORATORY INSTRUMENT MANUFACTURING
# 13409     ANALYTICAL LABORATORY INSTRUMENT MANUFACTURING
# 14108  AIR-CONDITIONING AND WARM AIR HEATING EQUIPMEN...
# 15233  OTHER PROFESSIONAL EQUIPMENT AND SUPPLIES MERC...
# 15235  OTHER PROFESSIONAL EQUIPMENT AND SUPPLIES MERC...
# 15254  OTHER PROFESSIONAL EQUIPMENT AND SUPPLIES MERC...
# 15256  OTHER PROFESSIONAL EQUIPMENT AND SUPPLIES MERC...
# 15413                                                NaN
# 15415                                                NaN
# 15420                             ARCHITECTURAL SERVICES
# 15421                             ARCHITECTURAL SERVICES
# 15424                             ARCHITECTURAL SERVICES
# 15426                                                NaN
# 15442                             ARCHITECTURAL SERVICES
# 15445                             ARCHITECTURAL SERVICES
# 15446  ALL OTHER PROFESSIONAL, SCIENTIFIC, AND TECHNI...
# 15447  ALL OTHER PROFESSIONAL, SCIENTIFIC, AND TECHNI...
# 15450  ALL OTHER PROFESSIONAL, SCIENTIFIC, AND TECHNI...
# 15452                             ARCHITECTURAL SERVICES
# 15453                             ARCHITECTURAL SERVICES
# 15454  ALL OTHER PROFESSIONAL, SCIENTIFIC, AND TECHNI...
# 16358                SECURITY GUARDS AND PATROL SERVICES
# 16433                  OFFICES OF REAL ESTATE APPRAISERS
# 17427  SERVICES FOR THE ELDERLY AND PERSONS WITH DISA...
# 18481  SERVICES FOR THE ELDERLY AND PERSONS WITH DISA...

# %%
# Reports all Hispanic American Owned Businesses and the number grants they have recieved 
hbe.groupby(['recipient_name'])['contract_award_unique_key'].count()
# Out:
# recipient_name
# BIODIRECT INC.                            4
# BLANCO, EDGAR E                           1
# BRUNETTE, MARIA                           1
# CONVERGENCE MEDICAL DEVICES INC.          1
# CORTES, DHARMA E                          3
# GVC CONSTRUCTION AND ENGINEERING, INC.    1
# MEDICAL SPECIALTIES DISTRIBUTORS, LLC     1
# MIKRON, INC                               5
# MOURA'S CLEANING SERVICE, INC.            2
# NEO-ADVENT TECHNOLOGIES LLC               1
# TERESA, TRIANA                            1
# UNIC PRO, INC.                            4
# Name: contract_award_unique_key, dtype: int64

# %%
# Reports all Black American Owned Businesses and the number grants they have recieved 
hbe.groupby(['recipient_name', 'naics_description'])['recipient_name', 'naics_description'].head()
# Out:
#                                recipient_name  \
# 980                           BLANCO, EDGAR E
# 2066   GVC CONSTRUCTION AND ENGINEERING, INC.
# 2142           MOURA'S CLEANING SERVICE, INC.
# 2159           MOURA'S CLEANING SERVICE, INC.
# 3656                          BRUNETTE, MARIA
# 4842              NEO-ADVENT TECHNOLOGIES LLC
# 5070                           UNIC PRO, INC.
# 7187                         CORTES, DHARMA E
# 7194                         CORTES, DHARMA E
# 7196                         CORTES, DHARMA E
# 7314                           BIODIRECT INC.
# 8423                           TERESA, TRIANA
# 11270                             MIKRON, INC
# 11343                             MIKRON, INC
# 11391                             MIKRON, INC
# 11639                          BIODIRECT INC.
# 11703        CONVERGENCE MEDICAL DEVICES INC.
# 12261                          BIODIRECT INC.
# 12289                          BIODIRECT INC.
# 12414   MEDICAL SPECIALTIES DISTRIBUTORS, LLC
# 14503                             MIKRON, INC
# 15773                          UNIC PRO, INC.
# 16302                          UNIC PRO, INC.
# 16438                          UNIC PRO, INC.
# 18353                             MIKRON, INC
#
#                                        naics_description
# 980                    ENVIRONMENTAL CONSULTING SERVICES
# 2066            HIGHWAY, STREET, AND BRIDGE CONSTRUCTION
# 2142                                 JANITORIAL SERVICES
# 2159                                 JANITORIAL SERVICES
# 3656   RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...
# 4842   RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...
# 5070                                LANDSCAPING SERVICES
# 7187   RESEARCH AND DEVELOPMENT IN THE SOCIAL SCIENCE...
# 7194   RESEARCH AND DEVELOPMENT IN THE SOCIAL SCIENCE...
# 7196   RESEARCH AND DEVELOPMENT IN THE SOCIAL SCIENCE...
# 7314   OTHER PROFESSIONAL EQUIPMENT AND SUPPLIES MERC...
# 8423             TRANSLATION AND INTERPRETATION SERVICES
# 11270  OTHER ELECTRONIC AND PRECISION EQUIPMENT REPAI...
# 11343                IRRADIATION APPARATUS MANUFACTURING
# 11391     ANALYTICAL LABORATORY INSTRUMENT MANUFACTURING
# 11639  OTHER PROFESSIONAL EQUIPMENT AND SUPPLIES MERC...
# 11703     ANALYTICAL LABORATORY INSTRUMENT MANUFACTURING
# 12261  OTHER PROFESSIONAL EQUIPMENT AND SUPPLIES MERC...
# 12289  OTHER PROFESSIONAL EQUIPMENT AND SUPPLIES MERC...
# 12414  MEDICAL, DENTAL, AND HOSPITAL EQUIPMENT AND SU...
# 14503                ALL OTHER BUSINESS SUPPORT SERVICES
# 15773                                JANITORIAL SERVICES
# 16302                           PARKING LOTS AND GARAGES
# 16438                                JANITORIAL SERVICES
# 18353     ANALYTICAL LABORATORY INSTRUMENT MANUFACTURING

# %%
# Reports the mean amount given to each Black American Owned Business
bbe.groupby(['recipient_name'])['obligated_amount'].mean()
# Out:
# recipient_name
# AKRIVIS TECHNOLOGIES, LLC            262186.000000
# APHIOS CORPORATION                   181159.666667
# ATAASK GLOBAL INC.                     7262.980000
# BAYASSOCIATES, INC.                   60697.000000
# BRYANT ASSOCIATES, INC.              349354.250000
# CLARENDON VALUATION ADVISORS, LLC     90543.090000
# COCKRELL, BEATRICE                     2971.666667
# GONA, PHILIMON                        33000.000000
# GORDON, PATRICK                        3306.000000
# HARLOW SCIENTIFIC, LLC                36045.000000
# INTELIMAP INC                         30325.000000
# JMW SYSTEMS                            7735.700000
# WESTCARB ENTERPRISES, INC.              468.320000
# WESTNET, INC.                         10751.934929
# WINDWALKER GROUP, LLC                497153.000000
# Name: obligated_amount, dtype: float64

# %%
# Reports the mean amount given to each Black American Owned Business
hbe.groupby(['recipient_name'])['obligated_amount'].mean()
# Out:
# recipient_name
# BIODIRECT INC.                             37317.325000
# BLANCO, EDGAR E                             1000.000000
# BRUNETTE, MARIA                            20000.000000
# CONVERGENCE MEDICAL DEVICES INC.           27000.000000
# CORTES, DHARMA E                            1678.056667
# GVC CONSTRUCTION AND ENGINEERING, INC.     57655.000000
# MEDICAL SPECIALTIES DISTRIBUTORS, LLC       9975.000000
# MIKRON, INC                                 6962.720000
# MOURA'S CLEANING SERVICE, INC.            910872.845000
# NEO-ADVENT TECHNOLOGIES LLC               497310.000000
# TERESA, TRIANA                              4858.500000
# UNIC PRO, INC.                            120761.272500
# Name: obligated_amount, dtype: float64

# %%
# Reports the difference in mean obligated amount between black owned and non-black owned businesses 
print(contracts['annual_revenue'].mean() )
print(contracts[contracts['minority_owned_business'] == True]['annual_revenue'].mean())
print(contracts[contracts['black_american_owned_business'] == True]['annual_revenue'].mean())
print(contracts[contracts['hispanic_american_owned_business'] == True]['annual_revenue'].mean())
# Out:
# 5818828338.933037
# 3623861.283333333
# 453811.76978417265
# 7790130.782608695

# %%
# Reports the difference in mean obligated amount between black owned and non-black owned businesses 
print(contracts['obligated_amount'].mean() )
print(contracts[contracts['minority_owned_business'] == True]['obligated_amount'].mean())
print(contracts[contracts['black_american_owned_business'] == True]['obligated_amount'].mean())
print(contracts[contracts['hispanic_american_owned_business'] == True]['obligated_amount'].mean())
# Out:
# 264245.84250229923
# 31068.202784679084
# 14998.489333333346
# 124468.254

# %%
# Reports the difference in mean obligated amount between black owned and non-black owned businesses 
contracts.groupby(['black_american_owned_business'])['obligated_amount'].mean()
# Out:
# black_american_owned_business
# False    272608.444521
# True      14998.489333
# Name: obligated_amount, dtype: float64

# %%
# Reports the difference in mean obligated amount between hispanic owned and non-black owned businesses 
contracts.groupby(['hispanic_american_owned_business'])['obligated_amount'].mean()
# Out:
# hispanic_american_owned_business
# False    264435.160939
# True     124468.254000
# Name: obligated_amount, dtype: float64

# %%
# Reports the difference in mean obligated amount between minority and non-minority owned businesses 
contracts.groupby(['minority_owned_business'])['obligated_amount'].mean()
# Out:
# minority_owned_business
# False    277104.756698
# True      31068.202785
# Name: obligated_amount, dtype: float64

# %%
# Reports the number of contracts given by each funding agency in the data 
contracts.groupby(['funding_agency_name'])[['contract_award_unique_key']].count()
# Out:
#                      contract_award_unique_key
# funding_agency_name
# DOT                                          4
# EPA                                       2699
# HHS                                      15487
# HUD                                        199
# NSF                                         94

# %%
# Reports the number of contracts given by each funding agency to black owned businesses 
bbe.groupby(['funding_agency_name'])[['contract_award_unique_key']].count()
# Out:
#                      contract_award_unique_key
# funding_agency_name
# EPA                                          9
# HHS                                        575
# HUD                                         16

# %%
# Reports the number of contracts given by each funding agency to hispanic owned businesses 
hbe.groupby(['funding_agency_name'])[['contract_award_unique_key']].count()
# Out:
#                      contract_award_unique_key
# funding_agency_name
# EPA                                          4
# HHS                                         21

# %%
# Reports the number of contracts given by each funding agency to minority owned businesses 
mbe.groupby(['funding_agency_name'])[['contract_award_unique_key']].count()
# Out:
#                      contract_award_unique_key
# funding_agency_name
# EPA                                         46
# HHS                                        903
# HUD                                         17

# %%
# Shows the number of contracts awarded by each funding agency to both black owned and non-black owned businesses
bbe.groupby(['funding_agency_name'])['contract_award_unique_key'].count().plot(kind="bar", legend=False)#.unstack().plot.bar()
#plt.legend(loc='center left')
plt.ylabel("Number of Grants Awarded")
plt.xlabel("Funding Agency")
plt.xticks(rotation="horizontal")
plt.title("Number of Grants Awarded to Black Owned Businesses by Funding Agency", fontsize=10)
plt.show()

# %%
# Shows the number of contracts awarded by each funding agency to both black owned and non-black owned businesses
hbe.groupby(['funding_agency_name'])['contract_award_unique_key'].count().plot(kind="bar" ,legend=False)#.unstack().plot.bar()
plt.ylabel("Number of Grants Awarded")
plt.xlabel("Funding Agency")
plt.xticks(rotation="horizontal")
plt.title("Number of Grants Awarded to Hispanic Owned Businesses by Funding Agency", fontsize=10)
plt.show()

# %%
# Shows the number of contracts awarded by each funding agency to both black owned and non-black owned businesses
mbe.groupby(['funding_agency_name'])['contract_award_unique_key'].count().plot(kind="bar", legend=False)#.unstack().plot.bar()
plt.ylabel("Number of Grants Awarded")
plt.xlabel("Funding Agency")
plt.xticks(rotation="horizontal")
plt.title("Number of Grants Awarded to Minority Owned Businesses by Funding Agency", fontsize=10)
plt.show()

# %%
# Shows the number of contracts awarded by each funding agency to both black owned and non-black owned businesses
contracts.groupby(['funding_agency_name'])['contract_award_unique_key'].count().plot(kind="bar", legend=False)#.unstack().plot.bar()
plt.ylabel("Number of Grants Awarded")
plt.xlabel("Funding Agency")
plt.xticks(rotation="horizontal")
plt.title("Number of Grants Awarded by Funding Agency", fontsize=10)
plt.show()

# %%
# Creates sub-frames for black, hispanic and minority owned businesses grouped by the funding agency
# Then the proportions of each minority group, for each funding agency
norm_mbe = contracts.groupby(['funding_agency_name'])['minority_owned_business'].value_counts(normalize=True).unstack()
norm_bbe = contracts.groupby(['funding_agency_name'])['black_american_owned_business'].value_counts(normalize=True).unstack()
norm_hbe = contracts.groupby(['funding_agency_name'])['hispanic_american_owned_business'].value_counts(normalize=True).unstack()

# %%
# Map the meaning of true/false so that labels are less confusing 
norm_mbe = norm_mbe.rename(columns={True: "Minority Owned", False: "Not Minority Owned"})
norm_bbe = norm_bbe.rename(columns={True: "Black Owned", False: "Not Black Owned"})
norm_hbe = norm_hbe.rename(columns={True: "Hispanic Owned", False: "Not Hispanic Owned"})

# %%
# Plots the proportions of each minority group recieving grants from individual funding agencies 


fig = plt.figure(figsize = [8, 4.8])
ax = fig.add_subplot(111)
fig.set_size_inches(16, 8)
fig.subplots_adjust(wspace = 0.)

norm_mbe.plot(kind='bar', stacked=True, width = 0.1, colormap="tab20", position=-0.5, ax=ax, align='center') 
norm_bbe.plot(kind='bar', stacked=True, width = 0.1, colormap="tab20b", position=0.5, ax=ax, align='center')
norm_hbe.plot(kind='bar', stacked=True, width = 0.1, colormap = "hot", position=1.5, ax=ax, align='center')

ax.spines['right'].set_smart_bounds

plt.legend(loc='lower left', 
           fontsize = 'medium')

plt.xlabel('Funding Agency', fontsize=18)
plt.ylabel('Proportion', fontsize=18)
plt.title("Proportions of Minorities by Funding Agency", fontsize=20)


plt.show()

# %%
rep_count = contracts.groupby('recipient_name')[['contract_award_unique_key']].count()
rep_count = rep_count.rename(columns={'contract_award_unique_key': 'number_of_grants'})

# %%
reps=rep_count.merge(contracts.groupby('recipient_name')[['annual_revenue']].mean(), left_index=True, right_index=True)

# %%
reps = reps.merge(contracts.groupby('recipient_name')[['minority_owned_business']].any(), left_index=True, right_index=True)

# %%
reps = reps.merge(contracts.groupby('recipient_name')[['black_american_owned_business']].any(), left_index=True, right_index=True)

# %%
reps = reps.merge(contracts.groupby('recipient_name')[['hispanic_american_owned_business']].any(), left_index=True, right_index=True)

# %%
reps_no = reps.dropna()

reps_no = reps_no[reps_no['annual_revenue'].astype(int) < 0.5e+11]
reps_no = reps_no[reps_no['number_of_grants'] < 20]

# %%
reps_no.plot(kind='scatter', x='number_of_grants', y='annual_revenue')
plt.xlabel('Number of Grants')#, fontsize=18)
plt.ylabel('Annual Revenue')#, fontsize=18)
plt.title("Number of Grants Recieved by an Enterprise against Annual Revenue\n " +
          "(For Enterprises with less than 20 grants \nand Revenue less than 50 Billion)", fontsize=8)

#xlocs()
#xlabs([100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400])

#locs, xlabs = plt.xticks()
#plt.xticks([100, 200, 300, 400, 500, 600, 700, 800])
# Out:
# Text(0.5, 1.0, 'Number of Grants Recieved by an Enterprise against Annual Revenue\n (For Enterprises with less than 20 grants \nand Revenue less than 50 Billion)')

# %%
bbe.groupby(['funding_agency_name', 'recipient_name'])[['contract_award_unique_key']].count().unstack().plot(kind='bar',stacked=True, legend=False)
plt.show()

# %%
#contracts.plot.scatter(x= 'obligated_amount', y='number_of_employees')#, c='black_american_owned_business', colormap='viridis')

# %%
# Reports the difference in the annual revenue between sole proprietorship and non-sole proprietorships
contracts.groupby(['sole_proprietorship'])['annual_revenue'].mean()
# Out:
# sole_proprietorship
# False    5.918330e+09
# True     1.730749e+09
# Name: annual_revenue, dtype: float64

# %%
contracts.groupby(['hispanic_american_owned_business', 'sole_proprietorship'])['recipient_name'].count()
# Out:
# hispanic_american_owned_business  sole_proprietorship
# False                             False                  17941
#                                   True                     517
# True                              False                     20
#                                   True                       5
# Name: recipient_name, dtype: int64

# %%
#contracts.groupby(['funding_agency_name'])
plt.suptitle('')
contracts[contracts['black_american_owned_business'] == True].boxplot(column=['obligated_amount'], by='funding_agency_name')

# %%
plt.suptitle('')
contracts[contracts['hispanic_american_owned_business'] == True].boxplot(column=['obligated_amount'], by='funding_agency_name')

# %%
plt.suptitle('')
contracts.boxplot(column=['obligated_amount'], by='funding_agency_name')

# %%
#contracts.groupby('sole_proprietorship')[''].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-172-a34615da5887> in <module>
# ----> 1 contracts.groupby('sole_proprietorship')[''].count()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/base.py in __getitem__(self, key)
#     273         else:
#     274             if key not in self.obj:
# --> 275                 raise KeyError("Column not found: {key}".format(key=key))
#     276             return self._gotitem(key, ndim=1)
#     277
#
# KeyError: 'Column not found: '

# %%
len(contracts[contracts['sole_proprietorship'] == True].groupby(['recipient_name'])['recipient_name'])
# Out:
# 103

# %%
len(contracts.groupby(['recipient_name'])['recipient_name'])
# Out:
# 1474

# %%
# Creates sub-frames for each minority group and calculates the number of sole proprietorships in each group
sole_mbe = mbe.groupby(['sole_proprietorship'])['contract_award_unique_key'].count()
sole_bbe = bbe.groupby(['sole_proprietorship'])['contract_award_unique_key'].count()
sole_hbe = hbe.groupby(['sole_proprietorship'])['contract_award_unique_key'].count()
sole_total = contracts.groupby('sole_proprietorship')['contract_award_unique_key'].count()

# %%
# Concatenates sub-frames in order to plot the proportions
sole_1 = pd.concat([sole_total, sole_mbe], axis=1, keys=["Total", "MBE"])
sole_2 = pd.concat([sole_bbe, sole_hbe], axis=1, keys=["BBE", "HBE"])
sole = pd.concat([sole_1, sole_2], axis=1)

# %%
# Turns the counts of sole proprietorships in each minority group into proportions for easier comparison 
sole['MBE'] = sole['MBE'] / sole['MBE'].sum()
sole['BBE'] = sole['BBE'] / sole['BBE'].sum()
sole['HBE'] = sole['HBE'] / sole['HBE'].sum()
sole['Total'] = sole['Total'] / sole['Total'].sum()

# %%
# Plots the proportions of sole proprietorships for each minority group and the whole set of contracts 
sole.plot(kind='bar')
plt.ylabel("Proportion")
plt.xlabel("Sole Proprietorship")
plt.xticks(rotation="horizontal")
plt.title("Proportion of Sole Proprietorship Enterprises based on Minority Group", fontsize=10)
plt.savefig("Proportion of Sole Proprietorship Enterprises based on Minority Group")

# %%
# Creates sub-frames with counts for the number of top naics for each minority (as true or false)
naics_mbe = mbe.groupby(['top_naics'])['contract_award_unique_key'].count()
naics_bbe = bbe.groupby(['top_naics'])['contract_award_unique_key'].count()
naics_hbe = hbe.groupby(['top_naics'])['contract_award_unique_key'].count()
naics_total = contracts.groupby(['top_naics'])['contract_award_unique_key'].count()

# %%
# Creates a dataframe with the counts of tops naics and non-top naics for each minority group
naics_1 = pd.concat([naics_total, naics_mbe], axis=1, keys=["Total", "MBE"])
naics_2 = pd.concat([naics_bbe, naics_hbe], axis=1, keys=["BBE", "HBE"])
naics_sum = pd.concat([naics_1, naics_2], axis=1)

# %%
# Manually calculate the proportions for each minority group 
naics_sum['MBE'] = naics_sum['MBE'] / naics_sum['MBE'].sum()
naics_sum['BBE'] = naics_sum['BBE'] / naics_sum['BBE'].sum()
naics_sum['HBE'] = naics_sum['HBE'] / naics_sum['HBE'].sum()
naics_sum['Total'] = naics_sum['Total'] / naics_sum['Total'].sum()

# %%
# Plots the proportions of top naics for each minority group
naics_sum.plot(kind='bar')
plt.ylabel("Proportion")
plt.xlabel("Tops Naics")
plt.xticks(rotation="horizontal")
plt.title("Proportion of Top Naics Enterprises based on Minority Group", fontsize=10)
plt.savefig("Proportion of Top Naics Enterprises based on Minority Group")

# %%
bbe_no_westnet = bbe[bbe['recipient_name'] != 'WESTNET, INC.']

# %%
# Creates sub-frames with counts for the number of top naics for each minority (as true or false)
naics_mbe = mbe.groupby(['top_naics'])['contract_award_unique_key'].count()
naics_bbe = bbe_no_westnet.groupby(['top_naics'])['contract_award_unique_key'].count()
naics_hbe = hbe.groupby(['top_naics'])['contract_award_unique_key'].count()
naics_total = contracts.groupby(['top_naics'])['contract_award_unique_key'].count()

# %%
# Creates a dataframe with the counts of tops naics and non-top naics for each minority group
naics_1 = pd.concat([naics_total, naics_mbe], axis=1, keys=["Total", "MBE"])
naics_2 = pd.concat([naics_bbe, naics_hbe], axis=1, keys=["BBE", "HBE"])
naics_sum = pd.concat([naics_1, naics_2], axis=1)

# %%
# Manually calculate the proportions for each minority group 
naics_sum['MBE'] = naics_sum['MBE'] / naics_sum['MBE'].sum()
naics_sum['BBE'] = naics_sum['BBE'] / naics_sum['BBE'].sum()
naics_sum['HBE'] = naics_sum['HBE'] / naics_sum['HBE'].sum()
naics_sum['Total'] = naics_sum['Total'] / naics_sum['Total'].sum()

# %%
# Plots the proportions of top naics for each minority group
naics_sum.plot(kind='bar')
plt.ylabel("Proportion")
plt.xlabel("Tops Naics")
plt.xticks(rotation="horizontal")
plt.title("Proportion of Top Naics Enterprises based on Minority Group (Without Westnet)", fontsize=10)
plt.savefig("Proportion of Top Naics Enterprises based on Minority Group")

# %%
bbe_naics = pd.Series(bbe['naics_description'].unique())
bbe_naics_counts = bbe_naics.isin(top_naics).value_counts()

# %%
def isin_topnaics(x):
    if (x in top_naics):
        return True
    else:
        return False

# %%
bbe_naics = pd.Series(bbe['naics_description'].unique())
bbe_naics_counts = bbe_naics.isin(top_naics).value_counts()

# %%
#bbe.groupby(['naics_description', 'recipient_name'], as_index=False)[['naics_description']].values#()#.apply(isin_topnaics)

# %%
#bbe.groupby(['naics_description', 'recipient_name'], as_index=False)[['naics_description']].head()

# %%
hbe_naics = pd.Series(hbe['naics_description'].unique())
hbe_naics_counts = hbe_naics.isin(top_naics).value_counts()

# %%
mbe_naics = pd.Series(mbe['naics_description'].unique())
mbe_naics_counts =mbe_naics.isin(top_naics).value_counts()

# %%
tot_naics = pd.Series(contracts['naics_description'].unique())
tot_naics_counts = tot_naics.isin(top_naics).value_counts()

# %%
# Concatenates sub-frames in order to plot the proportions
top_naics_1 = pd.concat([tot_naics_counts, mbe_naics_counts], axis=1, keys=["Total", "MBE"])
top_naics_2 = pd.concat([bbe_naics_counts, hbe_naics_counts], axis=1, keys=["BBE", "HBE"])
top_naics_minor = pd.concat([top_naics_1, top_naics_2], axis=1)

# %%
top_naics_minor
# Out:
#        Total  MBE  BBE  HBE
# False    343   50   13    9
# True      25   17    7    5

# %%
# Manually calculate the proportions for each minority group 
top_naics_minor['MBE'] = top_naics_minor['MBE'] / top_naics_minor['MBE'].sum()
top_naics_minor['BBE'] = top_naics_minor['BBE'] / top_naics_minor['BBE'].sum()
top_naics_minor['HBE'] = top_naics_minor['HBE'] / top_naics_minor['HBE'].sum()
top_naics_minor['Total'] = top_naics_minor['Total'] / top_naics_minor['Total'].sum()

# %%
top_naics_minor
# Out:
#           Total       MBE   BBE       HBE
# False  0.932065  0.746269  0.65  0.642857
# True   0.067935  0.253731  0.35  0.357143

# %%
# Plots the proportions of top naics for each minority group
top_naics_minor.plot(kind='bar')
plt.ylabel("Proportion")
plt.xlabel("Tops Naics")
plt.xticks(rotation="horizontal")
plt.title("Proportion of Top Naics Enterprises based on Minority Group", fontsize=10)
plt.savefig("Proportion of Top Naics Enterprises based on Minority Group")

# %%
def generateBaseMap(defaultlocation = [42.4072, -71.3824]):
    """Creates a basemap onto which datapoints can be added"""
    base_map = folium.Map(location = defaultlocation)
    return base_map

# %%
# Base Map Creation for Heatmap
base_map_total = generateBaseMap()

# Creates a heatmap, using the Folium Heatmap Plugin
heatmap_data_shuf = contracts[["Latitude_shuf", "Longitude_shuf"]] 
HeatMap(data = heatmap_data_shuf, radius=8, max_zoom=13).add_to(base_map_total)

# Saves the created basemap 
base_map_total.save('maps/total_contracts_map.html')
#display(base_map_total)

# %%
# Base Map Creation for Heatmap
base_map_bbe = generateBaseMap()

# Creates a heatmap, using the Folium Heatmap Plugin
heatmap_data = bbe[["Latitude_shuf", "Longitude_shuf"]] 
HeatMap(data = heatmap_data, radius=8, max_zoom=13).add_to(base_map_bbe)

# Saves the created basemap 
base_map_bbe.save('maps/bbe_contracts_map.html')
#display(base_map_bbe)

# %%
# Base Map Creation for Heatmap
base_map_hbe = generateBaseMap()

# Creates a heatmap, using the Folium Heatmap Plugin
heatmap_data = hbe[["Latitude_shuf", "Longitude_shuf"]]
HeatMap(data = heatmap_data, radius=8, max_zoom=13).add_to(base_map_hbe)

# Saves the created basemap 
base_map_hbe.save('maps/hbe_contracts_map.html')
#display(base_map_hbe)

# %%
# Base Map Creation for Heatmap
base_map_mbe = generateBaseMap()

# Creates a heatmap, using the Folium Heatmap Plugin
heatmap_data = mbe[["Latitude_shuf", "Longitude_shuf"]] 
HeatMap(data = heatmap_data, radius=8, max_zoom=25).add_to(base_map_mbe)

# Saves the created basemap 
base_map_mbe.save('maps/mbe_contracts_map.html')
#display(base_map_mbe)

# %%
boston_contracts = contracts[contracts['recipient_city_name'] == "BOSTON, MA"]

# %%
boston_contracts[boston_contracts['black_american_owned_business'] == True]
# Out:
#                              contract_award_unique_key  obligated_amount  \
# 62               CONT_AWD_0003_9700_W912WJ15D0002_9700          58676.00
# 112              CONT_AWD_0006_9700_W912WJ15D0002_9700         640032.50
# 551         CONT_AWD_DU204SB12P0025_8600_-NONE-_-NONE-         104408.00
# 6888   CONT_AWD_HHSI248201100079G_7527_GS21F0154W_4730            325.20
# 16358        CONT_AWD_68HE0D18C0030_6800_-NONE-_-NONE-         497153.00
# 16433                       CONT_IDV_DU204SA12C01_8600          76678.18
#
#       period_of_performance_start_date period_of_performance_current_end_date  \
# 62                              6/7/16                           6/20/17 0:00
# 112                            3/14/17                           9/14/18 0:00
# 551                            9/27/12                           9/26/14 0:00
# 6888                            5/5/11                           5/11/11 0:00
# 16358                          10/1/18                           9/30/20 0:00
# 16433                          6/15/12                                    NaN
#
#       funding_agency_name                       funding_sub_agency_name  \
# 62                    EPA               ENVIRONMENTAL PROTECTION AGENCY
# 112                   EPA               ENVIRONMENTAL PROTECTION AGENCY
# 551                   HUD  HOUSING AND URBAN DEVELOPMENT, DEPARTMENT OF
# 6888                  HHS                         INDIAN HEALTH SERVICE
# 16358                 EPA               ENVIRONMENTAL PROTECTION AGENCY
# 16433                 HUD  HOUSING AND URBAN DEVELOPMENT, DEPARTMENT OF
#
#                           recipient_name  \
# 62               BRYANT ASSOCIATES, INC.
# 112              BRYANT ASSOCIATES, INC.
# 551    CLARENDON VALUATION ADVISORS, LLC
# 6888          WESTCARB ENTERPRISES, INC.
# 16358              WINDWALKER GROUP, LLC
# 16433  CLARENDON VALUATION ADVISORS, LLC
#
#       primary_place_of_performance_county_name recipient_city_name  \
# 62                                     BRISTOL          BOSTON, MA
# 112                                    BRISTOL          BOSTON, MA
# 551                                   NEW YORK          BOSTON, MA
# 6888                                    MARION          BOSTON, MA
# 16358                               WASHINGTON          BOSTON, MA
# 16433                                      NaN          BOSTON, MA
#
#                                        naics_description  ...  \
# 62     SURVEYING AND MAPPING (EXCEPT GEOPHYSICAL) SER...  ...
# 112    SURVEYING AND MAPPING (EXCEPT GEOPHYSICAL) SER...  ...
# 551                    OFFICES OF REAL ESTATE APPRAISERS  ...
# 6888                       HARDWARE MERCHANT WHOLESALERS  ...
# 16358                SECURITY GUARDS AND PATROL SERVICES  ...
# 16433                  OFFICES OF REAL ESTATE APPRAISERS  ...
#
#        nonprofit_organization  other_not_for_profit_organization start_year  \
# 62                      False                              False         16
# 112                     False                              False         17
# 551                     False                              False         12
# 6888                    False                              False         11
# 16358                   False                              False         18
# 16433                   False                              False         12
#
#        end_year  top_naics   Latitude  Longitude  Latitude_shuf  \
# 62         17.0      False  42.360253 -71.058291      42.355811
# 112        18.0      False  42.360253 -71.058291      42.357400
# 551        14.0      False  42.360253 -71.058291      42.369630
# 6888       11.0      False  42.360253 -71.058291      42.369113
# 16358      20.0      False  42.360253 -71.058291      42.354604
# 16433       NaN      False  42.360253 -71.058291      42.354861
#
#        Longitude_shuf  con_len
# 62         -71.051961      1.0
# 112        -71.052598      1.0
# 551        -71.059102      2.0
# 6888       -71.055930      0.0
# 16358      -71.058558      2.0
# 16433      -71.061417      NaN
#
# [6 rows x 34 columns]

# %%
boston_contracts[boston_contracts['hispanic_american_owned_business'] == True]
# Out:
#                            contract_award_unique_key  obligated_amount  \
# 11703  CONT_AWD_HHSN271201300270P_7529_-NONE-_-NONE-           27000.0
#
#       period_of_performance_start_date period_of_performance_current_end_date  \
# 11703                          3/20/13                            5/1/13 0:00
#
#       funding_agency_name        funding_sub_agency_name  \
# 11703                 HHS  NATIONAL INSTITUTES OF HEALTH
#
#                          recipient_name  \
# 11703  CONVERGENCE MEDICAL DEVICES INC.
#
#       primary_place_of_performance_county_name recipient_city_name  \
# 11703                                MIDDLESEX          BOSTON, MA
#
#                                     naics_description  ...  \
# 11703  ANALYTICAL LABORATORY INSTRUMENT MANUFACTURING  ...
#
#        nonprofit_organization  other_not_for_profit_organization start_year  \
# 11703                   False                              False         13
#
#        end_year  top_naics   Latitude  Longitude  Latitude_shuf  \
# 11703      13.0       True  42.360253 -71.058291      42.361088
#
#        Longitude_shuf  con_len
# 11703      -71.050322      0.0
#
# [1 rows x 34 columns]

# %%
boston_contracts[boston_contracts['minority_owned_business'] == True]
# Out:
#                              contract_award_unique_key  obligated_amount  \
# 62               CONT_AWD_0003_9700_W912WJ15D0002_9700          58676.00
# 112              CONT_AWD_0006_9700_W912WJ15D0002_9700         640032.50
# 534          CONT_AWD_DU100R13P0007_8600_-NONE-_-NONE-           4000.00
# 551         CONT_AWD_DU204SB12P0025_8600_-NONE-_-NONE-         104408.00
# 3043    CONT_AWD_HHSD2002014M59655P_7523_-NONE-_-NONE-         150000.00
# 3097     CONT_AWD_HHSD200201564147C_7523_-NONE-_-NONE-        1000000.00
# 6104     CONT_AWD_HHSI245201300210P_7527_-NONE-_-NONE-          20468.00
# 6143     CONT_AWD_HHSI245201400013P_7527_-NONE-_-NONE-          19992.00
# 6198     CONT_AWD_HHSI245201500117P_7527_-NONE-_-NONE-          21420.00
# 6273     CONT_AWD_HHSI245201600305P_7527_-NONE-_-NONE-          24432.00
# 6357     CONT_AWD_HHSI245201700146P_7527_-NONE-_-NONE-          24960.00
# 6438     CONT_AWD_HHSI245201800209P_7527_-NONE-_-NONE-          24960.00
# 6888   CONT_AWD_HHSI248201100079G_7527_GS21F0154W_4730            325.20
# 11536    CONT_AWD_HHSN271201100015C_7529_-NONE-_-NONE-         150000.00
# 11703    CONT_AWD_HHSN271201300270P_7529_-NONE-_-NONE-          27000.00
# 14151   CONT_AWD_HHSN301201500127PC_7529_-NONE-_-NONE-           3200.00
# 16358        CONT_AWD_68HE0D18C0030_6800_-NONE-_-NONE-         497153.00
# 16433                       CONT_IDV_DU204SA12C01_8600          76678.18
# 17664       CONT_AWD_75N93019C00014_7529_-NONE-_-NONE-         599914.00
# 18158       CONT_AWD_75N93018C00017_7529_-NONE-_-NONE-         599997.00
#
#       period_of_performance_start_date period_of_performance_current_end_date  \
# 62                              6/7/16                           6/20/17 0:00
# 112                            3/14/17                           9/14/18 0:00
# 534                            1/28/13                           2/20/14 0:00
# 551                            9/27/12                           9/26/14 0:00
# 3043                            8/1/14                           3/15/15 0:00
# 3097                           9/29/15                           8/31/17 0:00
# 6104                          12/18/12                           9/30/13 0:00
# 6143                          10/18/13                          10/31/14 0:00
# 6198                          11/11/14                          12/31/15 0:00
# 6273                          12/22/15                          12/31/16 0:00
# 6357                           12/3/16                          12/31/17 0:00
# 6438                            1/7/18                          12/31/18 0:00
# 6888                            5/5/11                           5/11/11 0:00
# 11536                           9/1/11                           5/31/13 0:00
# 11703                          3/20/13                            5/1/13 0:00
# 14151                          5/13/15                           5/13/15 0:00
# 16358                          10/1/18                           9/30/20 0:00
# 16433                          6/15/12                                    NaN
# 17664                          6/17/19                           6/16/21 0:00
# 18158                          7/26/18                           7/31/20 0:00
#
#       funding_agency_name                       funding_sub_agency_name  \
# 62                    EPA               ENVIRONMENTAL PROTECTION AGENCY
# 112                   EPA               ENVIRONMENTAL PROTECTION AGENCY
# 534                   HUD  HOUSING AND URBAN DEVELOPMENT, DEPARTMENT OF
# 551                   HUD  HOUSING AND URBAN DEVELOPMENT, DEPARTMENT OF
# 3043                  HHS    CENTERS FOR DISEASE CONTROL AND PREVENTION
# 3097                  HHS    CENTERS FOR DISEASE CONTROL AND PREVENTION
# 6104                  HHS                         INDIAN HEALTH SERVICE
# 6143                  HHS                         INDIAN HEALTH SERVICE
# 6198                  HHS                         INDIAN HEALTH SERVICE
# 6273                  HHS                         INDIAN HEALTH SERVICE
# 6357                  HHS                         INDIAN HEALTH SERVICE
# 6438                  HHS                         INDIAN HEALTH SERVICE
# 6888                  HHS                         INDIAN HEALTH SERVICE
# 11536                 HHS                 NATIONAL INSTITUTES OF HEALTH
# 11703                 HHS                 NATIONAL INSTITUTES OF HEALTH
# 14151                 HHS                 NATIONAL INSTITUTES OF HEALTH
# 16358                 EPA               ENVIRONMENTAL PROTECTION AGENCY
# 16433                 HUD  HOUSING AND URBAN DEVELOPMENT, DEPARTMENT OF
# 17664                 HHS                 NATIONAL INSTITUTES OF HEALTH
# 18158                 HHS                 NATIONAL INSTITUTES OF HEALTH
#
#                           recipient_name  \
# 62               BRYANT ASSOCIATES, INC.
# 112              BRYANT ASSOCIATES, INC.
# 534                          YWCA BOSTON
# 551    CLARENDON VALUATION ADVISORS, LLC
# 3043       ANTAGEN PHARMACEUTICALS, INC.
# 3097       ANTAGEN PHARMACEUTICALS, INC.
# 6104                       SHIN, SONYA S
# 6143                       SHIN, SONYA S
# 6198                       SHIN, SONYA S
# 6273                       SHIN, SONYA S
# 6357                       SHIN, SONYA S
# 6438                       SHIN, SONYA S
# 6888          WESTCARB ENTERPRISES, INC.
# 11536      ANTAGEN PHARMACEUTICALS, INC.
# 11703   CONVERGENCE MEDICAL DEVICES INC.
# 14151                    ANGIO-PROTEOMIE
# 16358              WINDWALKER GROUP, LLC
# 16433  CLARENDON VALUATION ADVISORS, LLC
# 17664      ANTAGEN PHARMACEUTICALS, INC.
# 18158      ANTAGEN PHARMACEUTICALS, INC.
#
#       primary_place_of_performance_county_name recipient_city_name  \
# 62                                     BRISTOL          BOSTON, MA
# 112                                    BRISTOL          BOSTON, MA
# 534                                    SUFFOLK          BOSTON, MA
# 551                                   NEW YORK          BOSTON, MA
# 3043                                   SUFFOLK          BOSTON, MA
# 3097                                   SUFFOLK          BOSTON, MA
# 6104                                  MCKINLEY          BOSTON, MA
# 6143                                  MCKINLEY          BOSTON, MA
# 6198                                  MCKINLEY          BOSTON, MA
# 6273                                  MCKINLEY          BOSTON, MA
# 6357                                  MCKINLEY          BOSTON, MA
# 6438                                  MCKINLEY          BOSTON, MA
# 6888                                    MARION          BOSTON, MA
# 11536                                MIDDLESEX          BOSTON, MA
# 11703                                MIDDLESEX          BOSTON, MA
# 14151                               MONTGOMERY          BOSTON, MA
# 16358                               WASHINGTON          BOSTON, MA
# 16433                                      NaN          BOSTON, MA
# 17664                                  SUFFOLK          BOSTON, MA
# 18158                                  SUFFOLK          BOSTON, MA
#
#                                        naics_description  ...  \
# 62     SURVEYING AND MAPPING (EXCEPT GEOPHYSICAL) SER...  ...
# 112    SURVEYING AND MAPPING (EXCEPT GEOPHYSICAL) SER...  ...
# 534     PROFESSIONAL AND MANAGEMENT DEVELOPMENT TRAINING  ...
# 551                    OFFICES OF REAL ESTATE APPRAISERS  ...
# 3043            PHARMACEUTICAL PREPARATION MANUFACTURING  ...
# 3097           RESEARCH AND DEVELOPMENT IN BIOTECHNOLOGY  ...
# 6104   ALL OTHER PROFESSIONAL, SCIENTIFIC, AND TECHNI...  ...
# 6143   OFFICES OF PHYSICIANS (EXCEPT MENTAL HEALTH SP...  ...
# 6198   OFFICES OF PHYSICIANS (EXCEPT MENTAL HEALTH SP...  ...
# 6273   OFFICES OF PHYSICIANS (EXCEPT MENTAL HEALTH SP...  ...
# 6357   OFFICES OF PHYSICIANS (EXCEPT MENTAL HEALTH SP...  ...
# 6438   OFFICES OF PHYSICIANS (EXCEPT MENTAL HEALTH SP...  ...
# 6888                       HARDWARE MERCHANT WHOLESALERS  ...
# 11536  RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...  ...
# 11703     ANALYTICAL LABORATORY INSTRUMENT MANUFACTURING  ...
# 14151                    CUT AND SEW APPAREL CONTRACTORS  ...
# 16358                SECURITY GUARDS AND PATROL SERVICES  ...
# 16433                  OFFICES OF REAL ESTATE APPRAISERS  ...
# 17664  RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...  ...
# 18158  RESEARCH AND DEVELOPMENT IN BIOTECHNOLOGY (EXC...  ...
#
#        nonprofit_organization  other_not_for_profit_organization start_year  \
# 62                      False                              False         16
# 112                     False                              False         17
# 534                      True                              False         13
# 551                     False                              False         12
# 3043                    False                              False         14
# 3097                    False                              False         15
# 6104                    False                              False         12
# 6143                    False                              False         13
# 6198                    False                              False         14
# 6273                    False                              False         15
# 6357                    False                              False         16
# 6438                    False                              False         18
# 6888                    False                              False         11
# 11536                   False                              False         11
# 11703                   False                              False         13
# 14151                   False                              False         15
# 16358                   False                              False         18
# 16433                   False                              False         12
# 17664                   False                              False         19
# 18158                   False                              False         18
#
#        end_year  top_naics   Latitude  Longitude  Latitude_shuf  \
# 62         17.0      False  42.360253 -71.058291      42.355811
# 112        18.0      False  42.360253 -71.058291      42.357400
# 534        14.0      False  42.360253 -71.058291      42.363551
# 551        14.0      False  42.360253 -71.058291      42.369630
# 3043       15.0      False  42.360253 -71.058291      42.367770
# 3097       17.0       True  42.360253 -71.058291      42.353998
# 6104       13.0       True  42.360253 -71.058291      42.365638
# 6143       14.0       True  42.360253 -71.058291      42.359915
# 6198       15.0       True  42.360253 -71.058291      42.351416
# 6273       16.0       True  42.360253 -71.058291      42.359507
# 6357       17.0       True  42.360253 -71.058291      42.368050
# 6438       18.0       True  42.360253 -71.058291      42.363175
# 6888       11.0      False  42.360253 -71.058291      42.369113
# 11536      13.0       True  42.360253 -71.058291      42.367586
# 11703      13.0       True  42.360253 -71.058291      42.361088
# 14151      15.0      False  42.360253 -71.058291      42.363652
# 16358      20.0      False  42.360253 -71.058291      42.354604
# 16433       NaN      False  42.360253 -71.058291      42.354861
# 17664      21.0      False  42.360253 -71.058291      42.354590
# 18158      20.0      False  42.360253 -71.058291      42.365381
#
#        Longitude_shuf  con_len
# 62         -71.051961      1.0
# 112        -71.052598      1.0
# 534        -71.053954      1.0
# 551        -71.059102      2.0
# 3043       -71.064151      1.0
# 3097       -71.061262      2.0
# 6104       -71.051001      1.0
# 6143       -71.053006      1.0
# 6198       -71.056457      1.0
# 6273       -71.058393      1.0
# 6357       -71.051181      1.0
# 6438       -71.064675      0.0
# 6888       -71.055930      0.0
# 11536      -71.050895      2.0
# 11703      -71.050322      0.0
# 14151      -71.065697      0.0
# 16358      -71.058558      2.0
# 16433      -71.061417      NaN
# 17664      -71.066090      2.0
# 18158      -71.062846      2.0
#
# [20 rows x 34 columns]

# %%
contracts[contracts['nonprofit_organization'] == True]['number_of_employees'].mean()
# Out:
# 6380.432098765432

# %%
contracts['number_of_employees'].mean()
# Out:
# 15139.157179161371

# %%
len(contracts['recipient_name'].unique())
# Out:
# 1474

# %%
hbe
# Out:
#                                contract_award_unique_key  obligated_amount  \
# 980              CONT_AWD_EP11H000595_6800_-NONE-_-NONE-           1000.00
# 2066                CONT_AWD_EPC10063_6800_-NONE-_-NONE-          57655.00
# 2142                CONT_AWD_EPD11079_6800_-NONE-_-NONE-        1103327.99
# 2159                CONT_AWD_EPD16018_6800_-NONE-_-NONE-         718417.70
# 3656      CONT_AWD_HHSD2542010M34277P_7523_-NONE-_-NONE-          20000.00
# 4842       CONT_AWD_HHSF223201610093C_7524_-NONE-_-NONE-         497310.00
# 5070       CONT_AWD_HHSF223201810021A_7524_-NONE-_-NONE-          20000.00
# 7187       CONT_AWD_HHSM500201400074M_7530_-NONE-_-NONE-           1554.95
# 7194       CONT_AWD_HHSM500201500088M_7530_-NONE-_-NONE-           1642.22
# 7196       CONT_AWD_HHSM500201600012M_7530_-NONE-_-NONE-           1837.00
# 7314       CONT_AWD_HHSN261201000483P_7529_-NONE-_-NONE-          12722.50
# 8423   CONT_AWD_HHSN26300209_7529_HHSN263200200056616...           4858.50
# 11270      CONT_AWD_HHSN269201500509P_7529_-NONE-_-NONE-          14660.00
# 11343      CONT_AWD_HHSN269201600518P_7529_-NONE-_-NONE-           3743.60
# 11391      CONT_AWD_HHSN269201700234P_7529_-NONE-_-NONE-           7330.00
# 11639      CONT_AWD_HHSN271201200519P_7529_-NONE-_-NONE-           9234.00
# 11703      CONT_AWD_HHSN271201300270P_7529_-NONE-_-NONE-          27000.00
# 12261      CONT_AWD_HHSN272201000949P_7529_-NONE-_-NONE-         117929.80
# 12289      CONT_AWD_HHSN272201100168P_7529_-NONE-_-NONE-           9383.00
# 12414      CONT_AWD_HHSN272201300684P_7529_-NONE-_-NONE-           9975.00
# 14503      CONT_AWD_HHSN312201700013P_7529_-NONE-_-NONE-           1750.00
# 15773  CONT_AWD_HHSF22301001T_7524_HHSF223201810008C_...          40000.00
# 16302         CONT_AWD_75F40118P10283_7524_-NONE-_-NONE-          11750.00
# 16438                    CONT_IDV_HHSF223201810008C_7524         411295.09
# 18353         CONT_AWD_75N90018P00513_7529_-NONE-_-NONE-           7330.00
#
#       period_of_performance_start_date period_of_performance_current_end_date  \
# 980                             5/2/11                           5/22/11 0:00
# 2066                           9/28/10                          10/31/12 0:00
# 2142                            7/1/11                           6/30/16 0:00
# 2159                            7/1/16                           6/30/20 0:00
# 3656                           4/15/10                           9/15/10 0:00
# 4842                            9/6/16                           9/22/17 0:00
# 5070                           1/29/18                            2/3/18 0:00
# 7187                           7/30/14                          10/30/14 0:00
# 7194                           8/24/15                          10/30/15 0:00
# 7196                           7/11/16                          10/31/16 0:00
# 7314                           8/20/10                           9/13/10 0:00
# 8423                           5/23/12                           6/30/12 0:00
# 11270                          6/26/15                           6/26/17 0:00
# 11343                          6/13/16                           6/12/17 0:00
# 11391                          2/28/17                           6/26/18 0:00
# 11639                          7/25/12                           9/23/12 0:00
# 11703                          3/20/13                            5/1/13 0:00
# 12261                          8/31/10                           8/31/10 0:00
# 12289                         12/21/10                          12/21/10 0:00
# 12414                           7/3/13                           7/27/13 0:00
# 14503                          9/22/17                          10/31/17 0:00
# 15773                           3/7/18                            4/1/18 0:00
# 16302                          9/24/18                          11/23/18 0:00
# 16438                         12/28/17                                    NaN
# 18353                           6/6/18                           6/26/19 0:00
#
#       funding_agency_name                     funding_sub_agency_name  \
# 980                   EPA             ENVIRONMENTAL PROTECTION AGENCY
# 2066                  EPA             ENVIRONMENTAL PROTECTION AGENCY
# 2142                  EPA             ENVIRONMENTAL PROTECTION AGENCY
# 2159                  EPA             ENVIRONMENTAL PROTECTION AGENCY
# 3656                  HHS  CENTERS FOR DISEASE CONTROL AND PREVENTION
# 4842                  HHS                FOOD AND DRUG ADMINISTRATION
# 5070                  HHS                FOOD AND DRUG ADMINISTRATION
# 7187                  HHS  CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 7194                  HHS  CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 7196                  HHS  CENTERS FOR MEDICARE AND MEDICAID SERVICES
# 7314                  HHS               NATIONAL INSTITUTES OF HEALTH
# 8423                  HHS               NATIONAL INSTITUTES OF HEALTH
# 11270                 HHS               NATIONAL INSTITUTES OF HEALTH
# 11343                 HHS               NATIONAL INSTITUTES OF HEALTH
# 11391                 HHS               NATIONAL INSTITUTES OF HEALTH
# 11639                 HHS               NATIONAL INSTITUTES OF HEALTH
# 11703                 HHS               NATIONAL INSTITUTES OF HEALTH
# 12261                 HHS               NATIONAL INSTITUTES OF HEALTH
# 12289                 HHS               NATIONAL INSTITUTES OF HEALTH
# 12414                 HHS               NATIONAL INSTITUTES OF HEALTH
# 14503                 HHS               NATIONAL INSTITUTES OF HEALTH
# 15773                 HHS                FOOD AND DRUG ADMINISTRATION
# 16302                 HHS                FOOD AND DRUG ADMINISTRATION
# 16438                 HHS                FOOD AND DRUG ADMINISTRATION
# 18353                 HHS               NATIONAL INSTITUTES OF HEALTH
#
#                                recipient_name  \
# 980                           BLANCO, EDGAR E
# 2066   GVC CONSTRUCTION AND ENGINEERING, INC.
# 2142           MOURA'S CLEANING SERVICE, INC.
# 2159           MOURA'S CLEANING SERVICE, INC.
# 3656                          BRUNETTE, MARIA
# 4842              NEO-ADVENT TECHNOLOGIES LLC
# 5070                           UNIC PRO, INC.
# 7187                         CORTES, DHARMA E
# 7194                         CORTES, DHARMA E
# 7196                         CORTES, DHARMA E
# 7314                           BIODIRECT INC.
# 8423                           TERESA, TRIANA
# 11270                             MIKRON, INC
# 11343                             MIKRON, INC
# 11391                             MIKRON, INC
# 11639                          BIODIRECT INC.
# 11703        CONVERGENCE MEDICAL DEVICES INC.
# 12261                          BIODIRECT INC.
# 12289                          BIODIRECT INC.
# 12414   MEDICAL SPECIALTIES DISTRIBUTORS, LLC
# 14503                             MIKRON, INC
# 15773                          UNIC PRO, INC.
# 16302                          UNIC PRO, INC.
# 16438                          UNIC PRO, INC.
# 18353                             MIKRON, INC
#
#       primary_place_of_performance_county_name recipient_city_name  \
# 980                                  WASHTENAW       CAMBRIDGE, MA
# 2066                                WASHINGTON      LEOMINSTER, MA
# 2142                                 MIDDLESEX          HUDSON, MA
# 2159                                WASHINGTON       FITCHBURG, MA
# 3656                                 MIDDLESEX         BEDFORD, MA
# 4842                                 MIDDLESEX     MARLBOROUGH, MA
# 5070                                 MIDDLESEX      SHREWSBURY, MA
# 7187                                     ESSEX       CAMBRIDGE, MA
# 7194                                     ESSEX       CAMBRIDGE, MA
# 7196                                     ESSEX       CAMBRIDGE, MA
# 7314                                   BRISTOL         TAUNTON, MA
# 8423                                MONTGOMERY        FRANKLIN, MA
# 11270                               MONTGOMERY         WAREHAM, MA
# 11343                               MONTGOMERY         WAREHAM, MA
# 11391                               MONTGOMERY         WAREHAM, MA
# 11639                                BALTIMORE         TAUNTON, MA
# 11703                                MIDDLESEX          BOSTON, MA
# 12261                               MONTGOMERY         TAUNTON, MA
# 12289                               MONTGOMERY         TAUNTON, MA
# 12414                               MONTGOMERY       STOUGHTON, MA
# 14503                                 PLYMOUTH         WAREHAM, MA
# 15773                                MIDDLESEX      SHREWSBURY, MA
# 16302                                MIDDLESEX      SHREWSBURY, MA
# 16438                                      NaN      SHREWSBURY, MA
# 18353                               MONTGOMERY         WAREHAM, MA
#
#                                        naics_description  ...  \
# 980                    ENVIRONMENTAL CONSULTING SERVICES  ...
# 2066            HIGHWAY, STREET, AND BRIDGE CONSTRUCTION  ...
# 2142                                 JANITORIAL SERVICES  ...
# 2159                                 JANITORIAL SERVICES  ...
# 3656   RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...  ...
# 4842   RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGI...  ...
# 5070                                LANDSCAPING SERVICES  ...
# 7187   RESEARCH AND DEVELOPMENT IN THE SOCIAL SCIENCE...  ...
# 7194   RESEARCH AND DEVELOPMENT IN THE SOCIAL SCIENCE...  ...
# 7196   RESEARCH AND DEVELOPMENT IN THE SOCIAL SCIENCE...  ...
# 7314   OTHER PROFESSIONAL EQUIPMENT AND SUPPLIES MERC...  ...
# 8423             TRANSLATION AND INTERPRETATION SERVICES  ...
# 11270  OTHER ELECTRONIC AND PRECISION EQUIPMENT REPAI...  ...
# 11343                IRRADIATION APPARATUS MANUFACTURING  ...
# 11391     ANALYTICAL LABORATORY INSTRUMENT MANUFACTURING  ...
# 11639  OTHER PROFESSIONAL EQUIPMENT AND SUPPLIES MERC...  ...
# 11703     ANALYTICAL LABORATORY INSTRUMENT MANUFACTURING  ...
# 12261  OTHER PROFESSIONAL EQUIPMENT AND SUPPLIES MERC...  ...
# 12289  OTHER PROFESSIONAL EQUIPMENT AND SUPPLIES MERC...  ...
# 12414  MEDICAL, DENTAL, AND HOSPITAL EQUIPMENT AND SU...  ...
# 14503                ALL OTHER BUSINESS SUPPORT SERVICES  ...
# 15773                                JANITORIAL SERVICES  ...
# 16302                           PARKING LOTS AND GARAGES  ...
# 16438                                JANITORIAL SERVICES  ...
# 18353     ANALYTICAL LABORATORY INSTRUMENT MANUFACTURING  ...
#
#        nonprofit_organization  other_not_for_profit_organization start_year  \
# 980                     False                              False         11
# 2066                    False                              False         10
# 2142                    False                              False         11
# 2159                    False                              False         16
# 3656                    False                              False         10
# 4842                    False                              False         16
# 5070                    False                              False         18
# 7187                    False                              False         14
# 7194                    False                              False         15
# 7196                    False                              False         16
# 7314                    False                              False         10
# 8423                    False                              False         12
# 11270                   False                              False         15
# 11343                   False                              False         16
# 11391                   False                              False         17
# 11639                   False                              False         12
# 11703                   False                              False         13
# 12261                   False                              False         10
# 12289                   False                              False         10
# 12414                   False                              False         13
# 14503                   False                              False         17
# 15773                   False                              False         18
# 16302                   False                              False         18
# 16438                   False                              False         17
# 18353                   False                              False         18
#
#        end_year  top_naics   Latitude  Longitude  Latitude_shuf  \
# 980        11.0       True  42.375100 -71.105616      42.371031
# 2066       12.0      False  42.525091 -71.759794      42.523908
# 2142       16.0      False  42.391309 -71.567824      42.386964
# 2159       20.0      False  42.583423 -71.802296      42.590229
# 3656       10.0       True  42.491730 -71.281795      42.501103
# 4842       17.0       True  42.345927 -71.552287      42.352755
# 5070       18.0      False  42.297090 -71.713934      42.300495
# 7187       14.0      False  42.375100 -71.105616      42.379082
# 7194       15.0      False  42.375100 -71.105616      42.382050
# 7196       16.0      False  42.375100 -71.105616      42.369603
# 7314       10.0      False  41.894611 -71.111130      41.903482
# 8423       12.0      False  42.589621 -72.611064      42.591966
# 11270      17.0       True  41.762604 -70.721702      41.767610
# 11343      17.0      False  41.762604 -70.721702      41.756290
# 11391      18.0       True  41.762604 -70.721702      41.770822
# 11639      12.0      False  41.894611 -71.111130      41.900250
# 11703      13.0       True  42.360253 -71.058291      42.361088
# 12261      10.0      False  41.894611 -71.111130      41.892729
# 12289      10.0      False  41.894611 -71.111130      41.892018
# 12414      13.0       True  42.125099 -71.102271      42.128870
# 14503      17.0      False  41.762604 -70.721702      41.758703
# 15773      18.0      False  42.297090 -71.713934      42.293646
# 16302      18.0      False  42.297090 -71.713934      42.297442
# 16438       NaN      False  42.297090 -71.713934      42.287275
# 18353      19.0       True  41.762604 -70.721702      41.767647
#
#        Longitude_shuf  con_len
# 980        -71.107246      0.0
# 2066       -71.761493      2.0
# 2142       -71.564107      5.0
# 2159       -71.802776      4.0
# 3656       -71.272407      0.0
# 4842       -71.546503      1.0
# 5070       -71.714486      0.0
# 7187       -71.110870      0.0
# 7194       -71.113293      0.0
# 7196       -71.101715      0.0
# 7314       -71.110988      0.0
# 8423       -72.609039      0.0
# 11270      -70.717126      2.0
# 11343      -70.723614      1.0
# 11391      -70.724658      1.0
# 11639      -71.116500      0.0
# 11703      -71.050322      0.0
# 12261      -71.118711      0.0
# 12289      -71.115499      0.0
# 12414      -71.092417      0.0
# 14503      -70.716072      0.0
# 15773      -71.709705      0.0
# 16302      -71.708312      0.0
# 16438      -71.713957      NaN
# 18353      -70.727327      1.0
#
# [25 rows x 34 columns]

# %%
print(contracts['con_len'].mean())
# Out:
# 1.1532592108131676

# %%
print(mbe['con_len'].mean())
# Out:
# 0.6493236212278877

# %%
print(bbe['con_len'].mean())
# Out:
# 0.8046744574290484

# %%
print(hbe['con_len'].mean())
# Out:
# 0.7083333333333334

# %%
top_naics
# Out:
# Index(['ANALYTICAL LABORATORY INSTRUMENT MANUFACTURING', 'OFFICES OF LAWYERS',
#        'OTHER ELECTRONIC AND PRECISION EQUIPMENT REPAIR AND MAINTENANCE',
#        'SURGICAL AND MEDICAL INSTRUMENT MANUFACTURING',
#        'ENVIRONMENTAL CONSULTING SERVICES',
#        'ADMINISTRATIVE MANAGEMENT AND GENERAL MANAGEMENT CONSULTING SERVICES',
#        'SOFTWARE PUBLISHERS', 'RESEARCH AND DEVELOPMENT IN BIOTECHNOLOGY',
#        'BIOLOGICAL PRODUCT (EXCEPT DIAGNOSTIC) MANUFACTURING',
#        'TESTING LABORATORIES',
#        'OFFICES OF PHYSICIANS (EXCEPT MENTAL HEALTH SPECIALISTS)',
#        'SURGICAL APPLIANCE AND SUPPLIES MANUFACTURING',
#        'ALL OTHER PROFESSIONAL, SCIENTIFIC, AND TECHNICAL SERVICES',
#        'RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGINEERING, AND LIFE SCIENCES (EXCEPT BIOTECHNOLOGY)',
#        'OTHER MEASURING AND CONTROLLING DEVICE MANUFACTURING',
#        'MEDICAL, DENTAL, AND HOSPITAL EQUIPMENT AND SUPPLIES MERCHANT WHOLESALERS',
#        'ELECTROMEDICAL AND ELECTROTHERAPEUTIC APPARATUS MANUFACTURING',
#        'VETERINARY SERVICES',
#        'OTHER SCIENTIFIC AND TECHNICAL CONSULTING SERVICES',
#        'OTHER COMPUTER RELATED SERVICES', 'ALL OTHER ANIMAL PRODUCTION',
#        'IN-VITRO DIAGNOSTIC SUBSTANCE MANUFACTURING',
#        'CUSTOM COMPUTER PROGRAMMING SERVICES',
#        'ALL OTHER BASIC ORGANIC CHEMICAL MANUFACTURING',
#        'OFFICE FURNITURE (EXCEPT WOOD) MANUFACTURING'],
#       dtype='object', name='naics_description')

# %%
contracts.columns
# Out:
# Index(['contract_award_unique_key', 'obligated_amount',
#        'period_of_performance_start_date',
#        'period_of_performance_current_end_date', 'funding_agency_name',
#        'funding_sub_agency_name', 'recipient_name',
#        'primary_place_of_performance_county_name', 'recipient_city_name',
#        'naics_description', 'number_of_employees', 'annual_revenue',
#        'multi_year_contract_code', 'minority_owned_business',
#        'black_american_owned_business', 'hispanic_american_owned_business',
#        'federally_funded_research_and_development_corp', 'us_state_government',
#        'sole_proprietorship', 'us_government_entity',
#        'educational_institution', 'manufacturer_of_goods',
#        'limited_liability_corporation', 'for_profit_organization',
#        'nonprofit_organization', 'other_not_for_profit_organization',
#        'start_year', 'end_year', 'top_naics', 'Latitude', 'Longitude',
#        'Latitude_shuf', 'Longitude_shuf', 'con_len'],
#       dtype='object')

# %%
 contracts[contracts['naics_description'] == 'OFFICES OF LAWYERS'].groupby(['funding_agency_name'])['funding_agency_name'].count()
# Out:
# funding_agency_name
# HHS    1378
# HUD       2
# Name: funding_agency_name, dtype: int64

# %%
bbe['naics_description'].unique()
# Out:
# array(['SURVEYING AND MAPPING (EXCEPT GEOPHYSICAL) SERVICES',
#        'OFFICES OF REAL ESTATE APPRAISERS',
#        'ENVIRONMENTAL CONSULTING SERVICES',
#        'OTHER MANAGEMENT CONSULTING SERVICES', 'GRANTMAKING FOUNDATIONS',
#        'HARDWARE MERCHANT WHOLESALERS',
#        'RESEARCH AND DEVELOPMENT IN BIOTECHNOLOGY',
#        'SURGICAL AND MEDICAL INSTRUMENT MANUFACTURING',
#        'MEDICAL, DENTAL, AND HOSPITAL EQUIPMENT AND SUPPLIES MERCHANT WHOLESALERS',
#        'ANALYTICAL LABORATORY INSTRUMENT MANUFACTURING',
#        'OTHER PRESSED AND BLOWN GLASS AND GLASSWARE MANUFACTURING',
#        'ELECTRONIC COMPUTER MANUFACTURING',
#        'RESEARCH AND DEVELOPMENT IN THE PHYSICAL, ENGINEERING, AND LIFE SCIENCES (EXCEPT BIOTECHNOLOGY)',
#        'AIR-CONDITIONING AND WARM AIR HEATING EQUIPMENT AND COMMERCIAL AND INDUSTRIAL REFRIGERATION EQUIPMENT MANUFACTURING',
#        'OTHER PROFESSIONAL EQUIPMENT AND SUPPLIES MERCHANT WHOLESALERS',
#        nan, 'ARCHITECTURAL SERVICES',
#        'ALL OTHER PROFESSIONAL, SCIENTIFIC, AND TECHNICAL SERVICES',
#        'SECURITY GUARDS AND PATROL SERVICES',
#        'SERVICES FOR THE ELDERLY AND PERSONS WITH DISABILITIES'],
#       dtype=object)
